# %% [markdown]
# <a href="https://colab.research.google.com/github/carp-x/ML_Colab/blob/main/minitaur_/minitaur_ddpg_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **install**

# %%
# !pip install pybullet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pybullet
#   Downloading pybullet-3.2.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (91.7 MB)
#      |████████████████████████████████| 91.7 MB 1.9 MB/s
# Installing collected packages: pybullet
# Successfully installed pybullet-3.2.5

# %%
# !pip install ptan
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ptan
#   Downloading ptan-0.7.tar.gz (20 kB)
# Collecting torch==1.7.0
#   Downloading torch-1.7.0-cp37-cp37m-manylinux1_x86_64.whl (776.7 MB)
#      |████████████████████████████████| 776.7 MB 4.5 kB/s
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (from ptan) (0.17.3)
# Requirement already satisfied: atari-py in /usr/local/lib/python3.7/dist-packages (from ptan) (0.2.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ptan) (1.21.6)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from ptan) (4.1.2.30)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->ptan) (0.16.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->ptan) (4.2.0)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from atari-py->ptan) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym->ptan) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym->ptan) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym->ptan) (1.5.0)
# Building wheels for collected packages: ptan
#   Building wheel for ptan (setup.py) ... done
#   Created wheel for ptan: filename=ptan-0.7-py3-none-any.whl size=23505 sha256=a6d26bc7dd3de2a02d8006f8aa02df7ee09bfdce50fca9067e831599c61ba3cc
#   Stored in directory: /root/.cache/pip/wheels/60/72/3d/a3c47193fdb9efd08e3a54398af996b2989c68571813a71256
# Successfully built ptan
# Installing collected packages: dataclasses, torch, ptan
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.12.0+cu113 requires torch==1.11.0, but you have torch 1.7.0 which is incompatible.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.7.0 which is incompatible.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.7.0 which is incompatible.
# Successfully installed dataclasses-0.6 ptan-0.7 torch-1.7.0

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorboardX
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 9.6 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.21.6)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5

# %%
from google.colab import drive
drive.mount('./mount')
# Out:
# Mounted at ./mount

# %% [markdown]
# # **explore**

# %%
import gym
import pybullet_envs

env = gym.make("MinitaurBulletEnv-v0")
# Out:
# urdf_root=/usr/local/lib/python3.7/dist-packages/pybullet_data
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
xxx = env.render('rgb_array')
print(xxx.shape)

import matplotlib.pyplot as plt
plt.imshow(xxx)
# Out:
# (720, 960, 3)

# %%
# video recorder import
from gym.wrappers.monitoring.video_recorder import VideoRecorder

# video -> html function
from base64 import b64encode
def render_mp4(videopath: str) -> str:
  """
  Gets a string containing a b4-encoded version of the MP4 video
  at the specified path.
  """
  mp4 = open(videopath, 'rb').read()
  base64_encoded_mp4 = b64encode(mp4).decode()
  return f'<video width=400 controls><source src="data:video/mp4;' \
         f'base64,{base64_encoded_mp4}" type="video/mp4"></video>'

# %%
# video record

minitaur_training = "minitaur_training.mp4"
video = VideoRecorder(env, minitaur_training)

state = env.reset()
done = False
while not done:
  env.render()
  video.capture_frame()
  action = env.action_space.sample()
  _, _, done, info = env.step(action)

  pass

env.render()
video.capture_frame()

video.close()
env.close()

# %%
# video play

from IPython.display import HTML
html = render_mp4(minitaur_training)
HTML(html)

# %% [markdown]
# # **model**

# %%
# model

import ptan
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F

HID_SIZE = 128


class ModelA2C(nn.Module):
    def __init__(self, obs_size, act_size):
        super(ModelA2C, self).__init__()

        self.base = nn.Sequential(
            nn.Linear(obs_size, HID_SIZE),
            nn.ReLU(),
        )
        self.mu = nn.Sequential(
            nn.Linear(HID_SIZE, act_size),
            nn.Tanh(),
        )
        self.var = nn.Sequential(
            nn.Linear(HID_SIZE, act_size),
            nn.Softplus(),
        )
        self.value = nn.Linear(HID_SIZE, 1)

    def forward(self, x):
        base_out = self.base(x)
        return self.mu(base_out), self.var(base_out), \
               self.value(base_out)


class DDPGActor(nn.Module):
    def __init__(self, obs_size, act_size):
        super(DDPGActor, self).__init__()

        self.net = nn.Sequential(
            nn.Linear(obs_size, 400),
            nn.ReLU(),
            nn.Linear(400, 300),
            nn.ReLU(),
            nn.Linear(300, act_size),
            nn.Tanh()
        )

    def forward(self, x):
        return self.net(x)


class DDPGCritic(nn.Module):
    def __init__(self, obs_size, act_size):
        super(DDPGCritic, self).__init__()

        self.obs_net = nn.Sequential(
            nn.Linear(obs_size, 400),
            nn.ReLU(),
        )

        self.out_net = nn.Sequential(
            nn.Linear(400 + act_size, 300),
            nn.ReLU(),
            nn.Linear(300, 1)
        )

    def forward(self, x, a):
        obs = self.obs_net(x)
        return self.out_net(torch.cat([obs, a], dim=1))


class D4PGCritic(nn.Module):
    def __init__(self, obs_size, act_size,
                 n_atoms, v_min, v_max):
        super(D4PGCritic, self).__init__()

        self.obs_net = nn.Sequential(
            nn.Linear(obs_size, 400),
            nn.ReLU(),
        )

        self.out_net = nn.Sequential(
            nn.Linear(400 + act_size, 300),
            nn.ReLU(),
            nn.Linear(300, n_atoms)
        )

        delta = (v_max - v_min) / (n_atoms - 1)
        self.register_buffer("supports", torch.arange(
            v_min, v_max + delta, delta))

    def forward(self, x, a):
        obs = self.obs_net(x)
        return self.out_net(torch.cat([obs, a], dim=1))

    def distr_to_q(self, distr):
        weights = F.softmax(distr, dim=1) * self.supports
        res = weights.sum(dim=1)
        return res.unsqueeze(dim=-1)


class AgentA2C(ptan.agent.BaseAgent):
    def __init__(self, net, device="cpu"):
        self.net = net
        self.device = device

    def __call__(self, states, agent_states):
        states_v = ptan.agent.float32_preprocessor(states)
        states_v = states_v.to(self.device)

        mu_v, var_v, _ = self.net(states_v)
        mu = mu_v.data.cpu().numpy()
        sigma = torch.sqrt(var_v).data.cpu().numpy()
        actions = np.random.normal(mu, sigma)
        actions = np.clip(actions, -1, 1)
        return actions, agent_states


class AgentDDPG(ptan.agent.BaseAgent):
    """
    Agent implementing Orstein-Uhlenbeck exploration process
    """
    def __init__(self, net, device="cpu", ou_enabled=True,
                 ou_mu=0.0, ou_teta=0.15, ou_sigma=0.2,
                 ou_epsilon=1.0):
        self.net = net
        self.device = device
        self.ou_enabled = ou_enabled
        self.ou_mu = ou_mu
        self.ou_teta = ou_teta
        self.ou_sigma = ou_sigma
        self.ou_epsilon = ou_epsilon

    def initial_state(self):
        return None

    def __call__(self, states, agent_states):
        states_v = ptan.agent.float32_preprocessor(states)
        states_v = states_v.to(self.device)
        mu_v = self.net(states_v)
        actions = mu_v.data.cpu().numpy()

        if self.ou_enabled and self.ou_epsilon > 0:
            new_a_states = []
            for a_state, action in zip(agent_states, actions):
                if a_state is None:
                    a_state = np.zeros(
                        shape=action.shape, dtype=np.float32)
                a_state += self.ou_teta * (self.ou_mu - a_state)
                a_state += self.ou_sigma * np.random.normal(
                    size=action.shape)

                action += self.ou_epsilon * a_state
                new_a_states.append(a_state)
        else:
            new_a_states = agent_states

        actions = np.clip(actions, -1, 1)
        return actions, new_a_states


class AgentD4PG(ptan.agent.BaseAgent):
    """
    Agent implementing noisy agent
    """
    def __init__(self, net, device="cpu", epsilon=0.3):
        self.net = net
        self.device = device
        self.epsilon = epsilon

    def __call__(self, states, agent_states):
        states_v = ptan.agent.float32_preprocessor(states)
        states_v = states_v.to(self.device)
        mu_v = self.net(states_v)
        actions = mu_v.data.cpu().numpy()
        actions += self.epsilon * np.random.normal(
            size=actions.shape)
        actions = np.clip(actions, -1, 1)
        return actions, agent_states

# %% [markdown]
# # **common**

# %%
import numpy as np
import torch
from torch.autograd import Variable

import ptan


def unpack_batch_a2c(batch, net, last_val_gamma, device="cpu"):
    """
    Convert batch into training tensors
    :param batch:
    :param net:
    :return: states variable, actions tensor, reference values variable
    """
    states = []
    actions = []
    rewards = []
    not_done_idx = []
    last_states = []
    for idx, exp in enumerate(batch):
        states.append(exp.state)
        actions.append(exp.action)
        rewards.append(exp.reward)
        if exp.last_state is not None:
            not_done_idx.append(idx)
            last_states.append(exp.last_state)
    states_v = ptan.agent.float32_preprocessor(states).to(device)
    actions_v = torch.FloatTensor(actions).to(device)

    # handle rewards
    rewards_np = np.array(rewards, dtype=np.float32)
    if not_done_idx:
        last_states_v = ptan.agent.float32_preprocessor(last_states).to(device)
        last_vals_v = net(last_states_v)[2]
        last_vals_np = last_vals_v.data.cpu().numpy()[:, 0]
        rewards_np[not_done_idx] += last_val_gamma * last_vals_np

    ref_vals_v = torch.FloatTensor(rewards_np).to(device)
    return states_v, actions_v, ref_vals_v


def unpack_batch_ddqn(batch, device="cpu"):
    states, actions, rewards, dones, last_states = [], [], [], [], []
    for exp in batch:
        states.append(exp.state)
        actions.append(exp.action)
        rewards.append(exp.reward)
        dones.append(exp.last_state is None)
        if exp.last_state is None:
            last_states.append(exp.state)
        else:
            last_states.append(exp.last_state)
    states_v = ptan.agent.float32_preprocessor(states).to(device)
    actions_v = ptan.agent.float32_preprocessor(actions).to(device)
    rewards_v = ptan.agent.float32_preprocessor(rewards).to(device)
    last_states_v = ptan.agent.float32_preprocessor(last_states).to(device)
    dones_t = torch.BoolTensor(dones).to(device)
    return states_v, actions_v, rewards_v, dones_t, last_states_v

# %% [markdown]
# # **import & define**

# %%
import os
import ptan
import time
import gym
import pybullet_envs
# import argparse
from tensorboardX import SummaryWriter
import numpy as np

# from lib import model, common

import torch
import torch.optim as optim
import torch.nn.functional as F


ENV_ID = "MinitaurBulletEnv-v0"
GAMMA = 0.99
BATCH_SIZE = 64
LEARNING_RATE = 1e-4
REPLAY_SIZE = 100000
REPLAY_INITIAL = 10000

TEST_ITERS = 1000


def test_net(net, env, count=10, device="cpu"):
    rewards = 0.0
    steps = 0
    for _ in range(count):
        obs = env.reset()
        while True:
            obs_v = ptan.agent.float32_preprocessor([obs]).to(device)
            mu_v = net(obs_v)
            action = mu_v.squeeze(dim=0).data.cpu().numpy()
            action = np.clip(action, -1, 1)
            obs, reward, done, _ = env.step(action)
            rewards += reward
            steps += 1
            if done:
                break
    return rewards / count, steps / count

# %%
# cuda or not

if torch.cuda.is_available():
  torch.set_default_tensor_type(torch.cuda.FloatTensor)
  print("using cuda:",torch.cuda.get_device_name(0))
  pass

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# using cuda: Tesla P100-PCIE-16GB
# device(type='cuda')

# %%
"""
parser = argparse.ArgumentParser()
parser.add_argument("--cuda", default=False, action='store_true', help='Enable CUDA')
parser.add_argument("-n", "--name", required=True, help="Name of the run")
args = parser.parse_args()
device = torch.device("cuda" if args.cuda else "cpu")
"""

save_path = os.path.join('mount/My Drive/Colab Notebooks/minitaur_', '01_22053122')
os.makedirs(save_path, exist_ok=True)


env = gym.make(ENV_ID)
test_env = gym.make(ENV_ID)

act_net = DDPGActor(
    env.observation_space.shape[0],
    env.action_space.shape[0]).to(device)
crt_net = DDPGCritic(
    env.observation_space.shape[0],
    env.action_space.shape[0]).to(device)
print(act_net)
print(crt_net)
tgt_act_net = ptan.agent.TargetNet(act_net)
tgt_crt_net = ptan.agent.TargetNet(crt_net)

writer = SummaryWriter(comment="-ddpg_")
agent = AgentDDPG(act_net, device=device)
exp_source = ptan.experience.ExperienceSourceFirstLast(
    env, agent, gamma=GAMMA, steps_count=1)
buffer = ptan.experience.ExperienceReplayBuffer(
    exp_source, buffer_size=REPLAY_SIZE)
act_opt = optim.Adam(act_net.parameters(), lr=LEARNING_RATE)
crt_opt = optim.Adam(crt_net.parameters(), lr=LEARNING_RATE)
# Out:
# current_dir=/usr/local/lib/python3.7/dist-packages/pybullet_envs/bullet
# urdf_root=/usr/local/lib/python3.7/dist-packages/pybullet_data
# urdf_root=/usr/local/lib/python3.7/dist-packages/pybullet_data
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# DDPGActor(
#   (net): Sequential(
#     (0): Linear(in_features=28, out_features=400, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=400, out_features=300, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=300, out_features=8, bias=True)
#     (5): Tanh()
#   )
# )
# DDPGCritic(
#   (obs_net): Sequential(
#     (0): Linear(in_features=28, out_features=400, bias=True)
#     (1): ReLU()
#   )
#   (out_net): Sequential(
#     (0): Linear(in_features=408, out_features=300, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=300, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# # **train**

# %%
frame_idx = 0
best_reward = None

# %%
frame_idx = 0
best_reward = None
with ptan.common.utils.RewardTracker(writer) as tracker:
    with ptan.common.utils.TBMeanTracker(
            writer, batch_size=10) as tb_tracker:
        while True:
            frame_idx += 1
            buffer.populate(1)
            rewards_steps = exp_source.pop_rewards_steps()
            if rewards_steps:
                rewards, steps = zip(*rewards_steps)
                tb_tracker.track("episode_steps", steps[0], frame_idx)
                tracker.reward(rewards[0], frame_idx)

            if len(buffer) < REPLAY_INITIAL:
                continue

            batch = buffer.sample(BATCH_SIZE)
            states_v, actions_v, rewards_v, \
            dones_mask, last_states_v = \
                unpack_batch_ddqn(batch, device)

            # train critic
            crt_opt.zero_grad()
            q_v = crt_net(states_v, actions_v)
            last_act_v = tgt_act_net.target_model(
                last_states_v)
            q_last_v = tgt_crt_net.target_model(
                last_states_v, last_act_v)
            q_last_v[dones_mask] = 0.0
            q_ref_v = rewards_v.unsqueeze(dim=-1) + \
                      q_last_v * GAMMA
            critic_loss_v = F.mse_loss(q_v, q_ref_v.detach())
            critic_loss_v.backward()
            crt_opt.step()
            tb_tracker.track("loss_critic",
                              critic_loss_v, frame_idx)
            tb_tracker.track("critic_ref",
                              q_ref_v.mean(), frame_idx)

            # train actor
            act_opt.zero_grad()
            cur_actions_v = act_net(states_v)
            actor_loss_v = -crt_net(states_v, cur_actions_v)
            actor_loss_v = actor_loss_v.mean()
            actor_loss_v.backward()
            act_opt.step()
            tb_tracker.track("loss_actor",
                              actor_loss_v, frame_idx)

            tgt_act_net.alpha_sync(alpha=1 - 1e-3)
            tgt_crt_net.alpha_sync(alpha=1 - 1e-3)

            if frame_idx % TEST_ITERS == 0:
                ####
                if frame_idx % 300000 == 0:
                  act_net_name = os.path.join(save_path, "act_net.pth")
                  crt_net_name = os.path.join(save_path, "crt_net.pth")
                  torch.save(act_net.state_dict(), act_net_name)
                  torch.save(crt_net.state_dict(), crt_net_name)
                ####
                ts = time.time()
                rewards, steps = test_net(act_net, test_env, device=device)
                print("Test done in %.2f sec, reward %.3f, steps %d" % (
                    time.time() - ts, rewards, steps))
                writer.add_scalar("test_reward", rewards, frame_idx)
                writer.add_scalar("test_steps", steps, frame_idx)
                if best_reward is None or best_reward < rewards:
                    if best_reward is not None:
                        print("Best reward updated: %.3f -> %.3f" % (best_reward, rewards))
                        name = "best_%+.3f_%d.dat" % (rewards, frame_idx)
                        fname = os.path.join(save_path, name)
                        torch.save(act_net.state_dict(), fname)
                    best_reward = rewards

# training end
# Out:
# 230: done 2 episodes, mean reward -0.219, speed 105.69 f/s
# 316: done 4 episodes, mean reward -0.147, speed 83.38 f/s
# 735: done 6 episodes, mean reward -0.227, speed 126.66 f/s
# 1003: done 8 episodes, mean reward -0.179, speed 118.98 f/s
# 1128: done 11 episodes, mean reward -0.146, speed 92.24 f/s
# 1263: done 12 episodes, mean reward -0.133, speed 114.48 f/s
# 1417: done 13 episodes, mean reward -0.129, speed 117.01 f/s
# 1633: done 14 episodes, mean reward -0.116, speed 129.37 f/s
# 1993: done 15 episodes, mean reward -0.137, speed 132.92 f/s
# 2111: done 16 episodes, mean reward -0.140, speed 111.18 f/s
# 2231: done 18 episodes, mean reward -0.129, speed 92.91 f/s
# 2431: done 20 episodes, mean reward -0.130, speed 114.65 f/s
# 2630: done 21 episodes, mean reward -0.143, speed 120.28 f/s
# 2726: done 23 episodes, mean reward -0.138, speed 93.35 f/s
# 2965: done 25 episodes, mean reward -0.127, speed 118.27 f/s
# 3321: done 26 episodes, mean reward -0.139, speed 121.79 f/s
# 3444: done 28 episodes, mean reward -0.141, speed 104.53 f/s
# 3625: done 29 episodes, mean reward -0.138, speed 125.47 f/s
# 4117: done 31 episodes, mean reward -0.161, speed 124.07 f/s
# 4548: done 32 episodes, mean reward -0.174, speed 135.52 f/s
# 4645: done 34 episodes, mean reward -0.168, speed 95.89 f/s
# 4770: done 36 episodes, mean reward -0.164, speed 105.26 f/s
# 4920: done 37 episodes, mean reward -0.166, speed 123.34 f/s
# 5054: done 38 episodes, mean reward -0.164, speed 119.73 f/s
# 5199: done 40 episodes, mean reward -0.160, speed 113.92 f/s
# 5325: done 42 episodes, mean reward -0.156, speed 108.60 f/s
# 5473: done 44 episodes, mean reward -0.154, speed 109.56 f/s
# 5606: done 45 episodes, mean reward -0.154, speed 122.41 f/s
# 5723: done 46 episodes, mean reward -0.151, speed 107.02 f/s
# 6032: done 48 episodes, mean reward -0.148, speed 120.11 f/s
# 6186: done 50 episodes, mean reward -0.146, speed 105.76 f/s
# 6612: done 52 episodes, mean reward -0.144, speed 125.71 f/s
# 6799: done 54 episodes, mean reward -0.141, speed 111.59 f/s
# 7301: done 56 episodes, mean reward -0.141, speed 128.08 f/s
# 7418: done 57 episodes, mean reward -0.141, speed 108.80 f/s
# 7753: done 59 episodes, mean reward -0.141, speed 126.06 f/s
# 7914: done 60 episodes, mean reward -0.144, speed 122.27 f/s
# 8068: done 62 episodes, mean reward -0.137, speed 109.15 f/s
# 8269: done 63 episodes, mean reward -0.139, speed 125.37 f/s
# 8517: done 65 episodes, mean reward -0.141, speed 118.73 f/s
# 8790: done 66 episodes, mean reward -0.144, speed 128.93 f/s
# 8957: done 67 episodes, mean reward -0.146, speed 123.48 f/s
# 9059: done 70 episodes, mean reward -0.141, speed 81.34 f/s
# 9263: done 71 episodes, mean reward -0.138, speed 119.26 f/s
# 9372: done 73 episodes, mean reward -0.137, speed 97.71 f/s
# 9593: done 76 episodes, mean reward -0.134, speed 105.45 f/s
# 9691: done 78 episodes, mean reward -0.130, speed 94.65 f/s
# 9930: done 80 episodes, mean reward -0.130, speed 116.45 f/s
# Test done in 67.26 sec, reward 0.004, steps 808
# 10041: done 82 episodes, mean reward -0.128, speed 1.61 f/s
# 10108: done 83 episodes, mean reward -0.126, speed 52.55 f/s
# 10206: done 84 episodes, mean reward -0.125, speed 55.87 f/s
# 10302: done 86 episodes, mean reward -0.123, speed 50.44 f/s
# 10375: done 88 episodes, mean reward -0.120, speed 47.00 f/s
# 10454: done 90 episodes, mean reward -0.117, speed 47.95 f/s
# 10537: done 92 episodes, mean reward -0.114, speed 47.05 f/s
# 10607: done 93 episodes, mean reward -0.113, speed 51.06 f/s
# 10690: done 95 episodes, mean reward -0.110, speed 48.38 f/s
# 10762: done 97 episodes, mean reward -0.108, speed 47.46 f/s
# 10839: done 99 episodes, mean reward -0.105, speed 48.10 f/s
# 10912: done 101 episodes, mean reward -0.104, speed 46.72 f/s
# 10978: done 103 episodes, mean reward -0.099, speed 46.62 f/s
# Test done in 4.36 sec, reward 0.008, steps 36
# Best reward updated: 0.004 -> 0.008
# 11020: done 104 episodes, mean reward -0.097, speed 8.01 f/s
# 11091: done 106 episodes, mean reward -0.090, speed 47.38 f/s
# 11165: done 108 episodes, mean reward -0.089, speed 48.83 f/s
# 11236: done 110 episodes, mean reward -0.089, speed 45.87 f/s
# 11303: done 112 episodes, mean reward -0.088, speed 45.76 f/s
# 11381: done 114 episodes, mean reward -0.087, speed 47.95 f/s
# 11458: done 116 episodes, mean reward -0.080, speed 48.71 f/s
# 11549: done 118 episodes, mean reward -0.079, speed 50.66 f/s
# 11628: done 120 episodes, mean reward -0.076, speed 49.87 f/s
# 11713: done 122 episodes, mean reward -0.072, speed 52.29 f/s
# 11804: done 124 episodes, mean reward -0.068, speed 51.39 f/s
# 11883: done 126 episodes, mean reward -0.065, speed 51.78 f/s
# 11974: done 128 episodes, mean reward -0.061, speed 51.79 f/s
# Test done in 4.49 sec, reward 0.022, steps 42
# Best reward updated: 0.008 -> 0.022
# 12006: done 129 episodes, mean reward -0.060, speed 6.19 f/s
# 12096: done 131 episodes, mean reward -0.049, speed 50.54 f/s
# 12177: done 133 episodes, mean reward -0.044, speed 49.39 f/s
# 12334: done 135 episodes, mean reward -0.043, speed 54.60 f/s
# 12430: done 136 episodes, mean reward -0.043, speed 56.04 f/s
# 12530: done 138 episodes, mean reward -0.039, speed 52.37 f/s
# 12578: done 139 episodes, mean reward -0.038, speed 47.01 f/s
# 12633: done 140 episodes, mean reward -0.038, speed 51.35 f/s
# 12724: done 141 episodes, mean reward -0.040, speed 54.50 f/s
# 12827: done 142 episodes, mean reward -0.038, speed 54.85 f/s
# 12877: done 144 episodes, mean reward -0.036, speed 41.85 f/s
# 12965: done 145 episodes, mean reward -0.035, speed 55.20 f/s
# Test done in 3.83 sec, reward -0.020, steps 32
# 13044: done 147 episodes, mean reward -0.035, speed 14.50 f/s
# 13127: done 149 episodes, mean reward -0.034, speed 49.16 f/s
# 13187: done 150 episodes, mean reward -0.034, speed 53.17 f/s
# 13235: done 152 episodes, mean reward -0.032, speed 43.18 f/s
# 13279: done 154 episodes, mean reward -0.032, speed 41.37 f/s
# 13337: done 156 episodes, mean reward -0.029, speed 45.00 f/s
# 13390: done 158 episodes, mean reward -0.027, speed 44.95 f/s
# 13445: done 160 episodes, mean reward -0.023, speed 43.74 f/s
# 13500: done 162 episodes, mean reward -0.025, speed 44.84 f/s
# 13643: done 164 episodes, mean reward -0.023, speed 54.12 f/s
# 13707: done 166 episodes, mean reward -0.015, speed 47.94 f/s
# 13760: done 168 episodes, mean reward -0.013, speed 43.76 f/s
# 13819: done 170 episodes, mean reward -0.013, speed 46.13 f/s
# 13911: done 172 episodes, mean reward -0.013, speed 50.98 f/s
# 13968: done 174 episodes, mean reward -0.012, speed 45.57 f/s
# Test done in 3.12 sec, reward -0.018, steps 22
# 14045: done 176 episodes, mean reward -0.012, speed 16.39 f/s
# 14115: done 177 episodes, mean reward -0.013, speed 52.17 f/s
# 14174: done 178 episodes, mean reward -0.014, speed 48.71 f/s
# 14700: done 179 episodes, mean reward -0.020, speed 57.82 f/s
# 14808: done 181 episodes, mean reward -0.022, speed 53.34 f/s
# Test done in 10.26 sec, reward -0.027, steps 119
# 15012: done 182 episodes, mean reward -0.023, speed 14.90 f/s
# 15108: done 183 episodes, mean reward -0.024, speed 54.28 f/s
# 15163: done 185 episodes, mean reward -0.024, speed 45.28 f/s
# 15443: done 186 episodes, mean reward -0.024, speed 58.17 f/s
# 15500: done 188 episodes, mean reward -0.026, speed 44.84 f/s
# 15560: done 190 episodes, mean reward -0.027, speed 44.82 f/s
# 15621: done 192 episodes, mean reward -0.029, speed 46.56 f/s
# 15680: done 194 episodes, mean reward -0.030, speed 46.02 f/s
# 15744: done 196 episodes, mean reward -0.032, speed 46.42 f/s
# 15809: done 198 episodes, mean reward -0.033, speed 46.17 f/s
# 15870: done 200 episodes, mean reward -0.035, speed 46.72 f/s
# 15940: done 202 episodes, mean reward -0.036, speed 46.68 f/s
# Test done in 3.48 sec, reward -0.108, steps 28
# 16042: done 204 episodes, mean reward -0.037, speed 18.48 f/s
# 16090: done 206 episodes, mean reward -0.038, speed 43.53 f/s
# 16139: done 208 episodes, mean reward -0.040, speed 41.57 f/s
# 16200: done 210 episodes, mean reward -0.041, speed 46.84 f/s
# 16251: done 212 episodes, mean reward -0.042, speed 43.54 f/s
# 16326: done 214 episodes, mean reward -0.044, speed 48.41 f/s
# 16389: done 216 episodes, mean reward -0.047, speed 47.23 f/s
# 16443: done 218 episodes, mean reward -0.048, speed 44.31 f/s
# 16507: done 220 episodes, mean reward -0.050, speed 46.89 f/s
# 16561: done 222 episodes, mean reward -0.053, speed 45.29 f/s
# 16630: done 224 episodes, mean reward -0.055, speed 47.02 f/s
# 16687: done 226 episodes, mean reward -0.057, speed 45.02 f/s
# 16751: done 228 episodes, mean reward -0.058, speed 46.82 f/s
# 16804: done 230 episodes, mean reward -0.061, speed 44.62 f/s
# 16863: done 232 episodes, mean reward -0.062, speed 45.53 f/s
# 16917: done 234 episodes, mean reward -0.064, speed 45.09 f/s
# 16972: done 236 episodes, mean reward -0.064, speed 42.84 f/s
# Test done in 3.59 sec, reward -0.113, steps 28
# 17030: done 238 episodes, mean reward -0.066, speed 12.01 f/s
# 17085: done 240 episodes, mean reward -0.067, speed 44.45 f/s
# 17160: done 242 episodes, mean reward -0.066, speed 47.87 f/s
# 17227: done 244 episodes, mean reward -0.067, speed 46.14 f/s
# 17296: done 246 episodes, mean reward -0.068, speed 47.16 f/s
# 17357: done 248 episodes, mean reward -0.067, speed 44.41 f/s
# 17430: done 250 episodes, mean reward -0.065, speed 48.33 f/s
# 17501: done 252 episodes, mean reward -0.065, speed 47.23 f/s
# 17567: done 254 episodes, mean reward -0.064, speed 46.55 f/s
# 17638: done 256 episodes, mean reward -0.063, speed 48.81 f/s
# 17706: done 258 episodes, mean reward -0.062, speed 49.08 f/s
# 17758: done 260 episodes, mean reward -0.062, speed 45.75 f/s
# 17819: done 262 episodes, mean reward -0.062, speed 47.42 f/s
# 17885: done 264 episodes, mean reward -0.062, speed 48.50 f/s
# 17951: done 266 episodes, mean reward -0.062, speed 48.87 f/s
# Test done in 3.45 sec, reward -0.041, steps 27
# 18049: done 268 episodes, mean reward -0.060, speed 18.39 f/s
# 18119: done 270 episodes, mean reward -0.059, speed 47.79 f/s
# 18189: done 272 episodes, mean reward -0.059, speed 48.11 f/s
# 18252: done 274 episodes, mean reward -0.058, speed 47.66 f/s
# 18317: done 276 episodes, mean reward -0.057, speed 47.06 f/s
# 18392: done 278 episodes, mean reward -0.053, speed 49.66 f/s
# 18464: done 280 episodes, mean reward -0.045, speed 49.62 f/s
# 18526: done 282 episodes, mean reward -0.042, speed 47.57 f/s
# 18588: done 284 episodes, mean reward -0.040, speed 46.10 f/s
# 18653: done 286 episodes, mean reward -0.040, speed 47.04 f/s
# 18715: done 288 episodes, mean reward -0.040, speed 46.69 f/s
# 18765: done 290 episodes, mean reward -0.039, speed 42.65 f/s
# 18827: done 292 episodes, mean reward -0.038, speed 47.14 f/s
# 18883: done 294 episodes, mean reward -0.038, speed 46.45 f/s
# 18946: done 296 episodes, mean reward -0.037, speed 46.67 f/s
# Test done in 3.54 sec, reward -0.012, steps 28
# 19016: done 298 episodes, mean reward -0.036, speed 14.06 f/s
# 19081: done 300 episodes, mean reward -0.036, speed 46.52 f/s
# 19146: done 302 episodes, mean reward -0.034, speed 47.92 f/s
# 19210: done 304 episodes, mean reward -0.033, speed 47.98 f/s
# 19273: done 306 episodes, mean reward -0.032, speed 45.56 f/s
# 19332: done 308 episodes, mean reward -0.031, speed 46.76 f/s
# 19396: done 310 episodes, mean reward -0.030, speed 48.05 f/s
# 19459: done 312 episodes, mean reward -0.029, speed 46.32 f/s
# 19536: done 314 episodes, mean reward -0.027, speed 50.16 f/s
# 19597: done 315 episodes, mean reward -0.028, speed 53.36 f/s
# 19692: done 316 episodes, mean reward -0.030, speed 54.53 f/s
# 19893: done 317 episodes, mean reward -0.031, speed 57.74 f/s
# 19958: done 318 episodes, mean reward -0.031, speed 53.30 f/s
# Test done in 45.85 sec, reward -0.130, steps 614
# 20036: done 319 episodes, mean reward -0.030, speed 1.65 f/s
# 20505: done 320 episodes, mean reward -0.026, speed 58.32 f/s
# 20610: done 321 episodes, mean reward -0.030, speed 54.11 f/s
# 20678: done 322 episodes, mean reward -0.032, speed 52.10 f/s
# 20761: done 323 episodes, mean reward -0.033, speed 51.55 f/s
# 20827: done 324 episodes, mean reward -0.036, speed 51.18 f/s
# 20937: done 325 episodes, mean reward -0.040, speed 53.20 f/s
# Test done in 5.50 sec, reward -0.205, steps 51
# 21069: done 326 episodes, mean reward -0.044, speed 16.55 f/s
# 21151: done 327 episodes, mean reward -0.047, speed 54.16 f/s
# 21233: done 328 episodes, mean reward -0.051, speed 52.53 f/s
# 21488: done 329 episodes, mean reward -0.055, speed 55.70 f/s
# 21551: done 330 episodes, mean reward -0.058, speed 53.27 f/s
# 21607: done 331 episodes, mean reward -0.060, speed 49.65 f/s
# 21775: done 332 episodes, mean reward -0.061, speed 58.85 f/s
# 21902: done 333 episodes, mean reward -0.063, speed 57.18 f/s
# Test done in 8.71 sec, reward -0.327, steps 91
# 22019: done 334 episodes, mean reward -0.067, speed 10.85 f/s
# 22085: done 335 episodes, mean reward -0.070, speed 49.74 f/s
# 22136: done 336 episodes, mean reward -0.071, speed 49.99 f/s
# 22244: done 337 episodes, mean reward -0.073, speed 52.90 f/s
# 22310: done 338 episodes, mean reward -0.075, speed 51.27 f/s
# 22461: done 339 episodes, mean reward -0.080, speed 53.83 f/s
# 22519: done 340 episodes, mean reward -0.082, speed 48.89 f/s
# 22580: done 341 episodes, mean reward -0.084, speed 52.12 f/s
# 22641: done 342 episodes, mean reward -0.087, speed 51.15 f/s
# 22728: done 343 episodes, mean reward -0.092, speed 53.52 f/s
# 22822: done 344 episodes, mean reward -0.096, speed 53.49 f/s
# 22886: done 345 episodes, mean reward -0.100, speed 51.79 f/s
# 22972: done 346 episodes, mean reward -0.102, speed 54.97 f/s
# Test done in 5.70 sec, reward -0.392, steps 62
# 23066: done 347 episodes, mean reward -0.102, speed 12.68 f/s
# 23144: done 348 episodes, mean reward -0.103, speed 55.40 f/s
# 23485: done 349 episodes, mean reward -0.109, speed 58.57 f/s
# 23550: done 350 episodes, mean reward -0.112, speed 51.95 f/s
# 23675: done 352 episodes, mean reward -0.115, speed 52.46 f/s
# 23729: done 353 episodes, mean reward -0.118, speed 50.93 f/s
# 23815: done 354 episodes, mean reward -0.120, speed 57.48 f/s
# 23875: done 355 episodes, mean reward -0.123, speed 52.50 f/s
# 23986: done 356 episodes, mean reward -0.124, speed 55.48 f/s
# Test done in 9.01 sec, reward -0.442, steps 107
# 24059: done 357 episodes, mean reward -0.128, speed 7.06 f/s
# 24240: done 358 episodes, mean reward -0.131, speed 58.09 f/s
# 24347: done 360 episodes, mean reward -0.135, speed 50.88 f/s
# 24412: done 361 episodes, mean reward -0.139, speed 53.79 f/s
# 24476: done 362 episodes, mean reward -0.142, speed 54.60 f/s
# 24878: done 364 episodes, mean reward -0.148, speed 59.55 f/s
# 24969: done 365 episodes, mean reward -0.149, speed 59.41 f/s
# Test done in 8.54 sec, reward -0.389, steps 105
# 25111: done 366 episodes, mean reward -0.150, speed 12.94 f/s
# 25207: done 368 episodes, mean reward -0.154, speed 52.45 f/s
# 25294: done 369 episodes, mean reward -0.156, speed 54.74 f/s
# 25459: done 370 episodes, mean reward -0.162, speed 58.25 f/s
# 25545: done 371 episodes, mean reward -0.161, speed 56.35 f/s
# 25724: done 373 episodes, mean reward -0.161, speed 55.62 f/s
# 25806: done 375 episodes, mean reward -0.164, speed 50.76 f/s
# 25979: done 377 episodes, mean reward -0.166, speed 55.95 f/s
# Test done in 4.11 sec, reward -0.004, steps 38
# 26045: done 378 episodes, mean reward -0.167, speed 12.23 f/s
# 26210: done 380 episodes, mean reward -0.168, speed 56.59 f/s
# 26643: done 381 episodes, mean reward -0.169, speed 60.10 f/s
# 26762: done 382 episodes, mean reward -0.167, speed 57.30 f/s
# 26884: done 383 episodes, mean reward -0.168, speed 57.36 f/s
# 26997: done 384 episodes, mean reward -0.165, speed 57.03 f/s
# Test done in 7.39 sec, reward -0.094, steps 89
# 27036: done 385 episodes, mean reward -0.165, speed 4.77 f/s
# 27128: done 387 episodes, mean reward -0.165, speed 50.14 f/s
# 27231: done 389 episodes, mean reward -0.166, speed 51.93 f/s
# 27312: done 391 episodes, mean reward -0.167, speed 48.94 f/s
# 27380: done 392 episodes, mean reward -0.167, speed 53.72 f/s
# 27508: done 394 episodes, mean reward -0.165, speed 53.93 f/s
# 27799: done 395 episodes, mean reward -0.167, speed 61.34 f/s
# 27907: done 397 episodes, mean reward -0.164, speed 54.71 f/s
# Test done in 5.74 sec, reward 0.061, steps 62
# Best reward updated: 0.022 -> 0.061
# 28015: done 398 episodes, mean reward -0.163, speed 14.16 f/s
# 28087: done 399 episodes, mean reward -0.163, speed 52.84 f/s
# 28215: done 401 episodes, mean reward -0.161, speed 54.61 f/s
# 28304: done 403 episodes, mean reward -0.162, speed 49.87 f/s
# 28375: done 405 episodes, mean reward -0.163, speed 48.58 f/s
# 28476: done 407 episodes, mean reward -0.162, speed 51.63 f/s
# 28586: done 408 episodes, mean reward -0.163, speed 56.01 f/s
# 28686: done 410 episodes, mean reward -0.164, speed 50.94 f/s
# 28762: done 411 episodes, mean reward -0.164, speed 55.90 f/s
# 28848: done 413 episodes, mean reward -0.164, speed 49.31 f/s
# 28967: done 414 episodes, mean reward -0.164, speed 57.51 f/s
# Test done in 6.59 sec, reward 0.003, steps 75
# 29050: done 415 episodes, mean reward -0.163, speed 10.27 f/s
# 29144: done 417 episodes, mean reward -0.160, speed 51.63 f/s
# 29306: done 418 episodes, mean reward -0.154, speed 56.96 f/s
# 29379: done 419 episodes, mean reward -0.152, speed 54.69 f/s
# 29457: done 420 episodes, mean reward -0.155, speed 53.59 f/s
# 29549: done 421 episodes, mean reward -0.149, speed 56.18 f/s
# 29753: done 422 episodes, mean reward -0.150, speed 59.47 f/s
# 29813: done 423 episodes, mean reward -0.149, speed 51.98 f/s
# 29890: done 424 episodes, mean reward -0.143, speed 54.02 f/s
# 29985: done 425 episodes, mean reward -0.137, speed 56.61 f/s
# Test done in 5.00 sec, reward 0.036, steps 53
# 30137: done 426 episodes, mean reward -0.133, speed 19.92 f/s
# 30240: done 428 episodes, mean reward -0.126, speed 52.40 f/s
# 30329: done 429 episodes, mean reward -0.120, speed 55.64 f/s
# 30428: done 431 episodes, mean reward -0.114, speed 50.81 f/s
# 30556: done 432 episodes, mean reward -0.113, speed 60.99 f/s
# 30630: done 433 episodes, mean reward -0.108, speed 56.19 f/s
# 30752: done 435 episodes, mean reward -0.101, speed 54.87 f/s
# 30848: done 436 episodes, mean reward -0.103, speed 59.06 f/s
# 30936: done 437 episodes, mean reward -0.100, speed 58.12 f/s
# Test done in 8.80 sec, reward 0.043, steps 111
# 31107: done 439 episodes, mean reward -0.095, speed 14.35 f/s
# 31390: done 440 episodes, mean reward -0.098, speed 63.10 f/s
# 31553: done 442 episodes, mean reward -0.090, speed 56.64 f/s
# 31789: done 444 episodes, mean reward -0.081, speed 59.23 f/s
# 31894: done 446 episodes, mean reward -0.074, speed 52.49 f/s
# 31956: done 448 episodes, mean reward -0.073, speed 48.30 f/s
# Test done in 3.75 sec, reward -0.058, steps 33
# 32101: done 450 episodes, mean reward -0.064, speed 23.11 f/s
# 32165: done 452 episodes, mean reward -0.060, speed 48.94 f/s
# 32230: done 454 episodes, mean reward -0.056, speed 48.90 f/s
# 32293: done 456 episodes, mean reward -0.054, speed 48.65 f/s
# 32357: done 458 episodes, mean reward -0.049, speed 48.89 f/s
# 32442: done 460 episodes, mean reward -0.045, speed 51.24 f/s
# 32540: done 462 episodes, mean reward -0.038, speed 53.59 f/s
# 32613: done 464 episodes, mean reward -0.031, speed 51.52 f/s
# 32881: done 466 episodes, mean reward -0.032, speed 60.68 f/s
# Test done in 4.13 sec, reward 0.044, steps 38
# 33035: done 467 episodes, mean reward -0.029, speed 22.91 f/s
# 33117: done 469 episodes, mean reward -0.026, speed 49.32 f/s
# 33254: done 470 episodes, mean reward -0.017, speed 58.43 f/s
# 33494: done 471 episodes, mean reward -0.014, speed 60.66 f/s
# 33571: done 473 episodes, mean reward -0.015, speed 49.59 f/s
# 33627: done 474 episodes, mean reward -0.012, speed 53.41 f/s
# 33786: done 475 episodes, mean reward -0.012, speed 59.19 f/s
# 33862: done 477 episodes, mean reward -0.013, speed 48.20 f/s
# 33981: done 479 episodes, mean reward -0.013, speed 51.15 f/s
# Test done in 4.61 sec, reward -0.025, steps 45
# 34036: done 480 episodes, mean reward -0.014, speed 9.73 f/s
# 34107: done 482 episodes, mean reward -0.014, speed 49.97 f/s
# 34177: done 484 episodes, mean reward -0.018, speed 48.89 f/s
# 34277: done 486 episodes, mean reward -0.018, speed 51.79 f/s
# 34350: done 487 episodes, mean reward -0.017, speed 56.11 f/s
# 34409: done 488 episodes, mean reward -0.017, speed 53.52 f/s
# 34464: done 489 episodes, mean reward -0.016, speed 52.83 f/s
# 34621: done 491 episodes, mean reward -0.019, speed 54.44 f/s
# 34748: done 493 episodes, mean reward -0.018, speed 53.43 f/s
# 34816: done 494 episodes, mean reward -0.021, speed 55.49 f/s
# 34877: done 495 episodes, mean reward -0.020, speed 53.84 f/s
# 34959: done 496 episodes, mean reward -0.016, speed 55.71 f/s
# Test done in 7.54 sec, reward -0.045, steps 91
# 35098: done 497 episodes, mean reward -0.017, speed 13.98 f/s
# 35177: done 498 episodes, mean reward -0.016, speed 53.74 f/s
# 35257: done 499 episodes, mean reward -0.014, speed 55.89 f/s
# 35333: done 500 episodes, mean reward -0.013, speed 54.35 f/s
# 35421: done 502 episodes, mean reward -0.014, speed 49.12 f/s
# 35487: done 503 episodes, mean reward -0.013, speed 52.29 f/s
# 35595: done 504 episodes, mean reward -0.015, speed 56.65 f/s
# 35708: done 506 episodes, mean reward -0.014, speed 51.60 f/s
# 35821: done 507 episodes, mean reward -0.015, speed 56.46 f/s
# 35921: done 508 episodes, mean reward -0.010, speed 56.30 f/s
# Test done in 5.65 sec, reward 0.098, steps 61
# Best reward updated: 0.061 -> 0.098
# 36006: done 510 episodes, mean reward -0.008, speed 11.57 f/s
# 36131: done 511 episodes, mean reward -0.008, speed 57.35 f/s
# 36280: done 512 episodes, mean reward -0.009, speed 58.57 f/s
# 36555: done 514 episodes, mean reward -0.014, speed 57.92 f/s
# 36645: done 515 episodes, mean reward -0.011, speed 56.13 f/s
# 36871: done 517 episodes, mean reward -0.011, speed 57.75 f/s
# Test done in 7.99 sec, reward 0.080, steps 98
# 37309: done 518 episodes, mean reward -0.031, speed 29.21 f/s
# 37376: done 519 episodes, mean reward -0.032, speed 57.29 f/s
# 37513: done 520 episodes, mean reward -0.035, speed 60.14 f/s
# 37606: done 521 episodes, mean reward -0.039, speed 58.55 f/s
# 37701: done 523 episodes, mean reward -0.036, speed 51.68 f/s
# 37764: done 524 episodes, mean reward -0.037, speed 53.03 f/s
# 37907: done 525 episodes, mean reward -0.043, speed 57.30 f/s
# Test done in 7.00 sec, reward -0.214, steps 80
# 38182: done 527 episodes, mean reward -0.042, speed 23.57 f/s
# 38326: done 528 episodes, mean reward -0.048, speed 57.37 f/s
# 38485: done 529 episodes, mean reward -0.048, speed 57.21 f/s
# 38795: done 530 episodes, mean reward -0.056, speed 59.08 f/s
# 38856: done 531 episodes, mean reward -0.055, speed 51.55 f/s
# Test done in 7.73 sec, reward -0.122, steps 94
# 39001: done 532 episodes, mean reward -0.058, speed 14.18 f/s
# 39085: done 533 episodes, mean reward -0.061, speed 53.88 f/s
# 39187: done 534 episodes, mean reward -0.060, speed 57.22 f/s
# 39262: done 535 episodes, mean reward -0.061, speed 54.15 f/s
# 39319: done 536 episodes, mean reward -0.057, speed 52.36 f/s
# 39679: done 537 episodes, mean reward -0.062, speed 60.86 f/s
# 39805: done 538 episodes, mean reward -0.063, speed 58.17 f/s
# 39903: done 539 episodes, mean reward -0.064, speed 54.94 f/s
# Test done in 7.84 sec, reward -0.003, steps 95
# 40143: done 540 episodes, mean reward -0.059, speed 20.20 f/s
# 40251: done 541 episodes, mean reward -0.058, speed 58.36 f/s
# 40337: done 543 episodes, mean reward -0.057, speed 52.10 f/s
# 40391: done 544 episodes, mean reward -0.056, speed 53.53 f/s
# 40603: done 545 episodes, mean reward -0.055, speed 58.68 f/s
# 40813: done 547 episodes, mean reward -0.059, speed 55.59 f/s
# 40889: done 548 episodes, mean reward -0.059, speed 55.17 f/s
# Test done in 7.70 sec, reward -0.016, steps 94
# 41023: done 550 episodes, mean reward -0.061, speed 13.18 f/s
# 41140: done 552 episodes, mean reward -0.064, speed 52.92 f/s
# 41352: done 553 episodes, mean reward -0.064, speed 59.31 f/s
# 41489: done 554 episodes, mean reward -0.064, speed 56.49 f/s
# 41563: done 555 episodes, mean reward -0.063, speed 54.83 f/s
# 41658: done 556 episodes, mean reward -0.061, speed 57.14 f/s
# 41775: done 557 episodes, mean reward -0.063, speed 57.85 f/s
# 41867: done 558 episodes, mean reward -0.064, speed 54.27 f/s
# 41926: done 559 episodes, mean reward -0.063, speed 51.68 f/s
# Test done in 6.53 sec, reward -0.149, steps 74
# 42024: done 560 episodes, mean reward -0.065, speed 11.81 f/s
# 42165: done 561 episodes, mean reward -0.062, speed 57.96 f/s
# 42306: done 562 episodes, mean reward -0.067, speed 55.70 f/s
# 42389: done 563 episodes, mean reward -0.070, speed 51.16 f/s
# 42462: done 564 episodes, mean reward -0.070, speed 54.77 f/s
# 42561: done 565 episodes, mean reward -0.069, speed 57.91 f/s
# 42734: done 566 episodes, mean reward -0.068, speed 58.60 f/s
# 42804: done 567 episodes, mean reward -0.069, speed 54.80 f/s
# 42877: done 568 episodes, mean reward -0.067, speed 54.40 f/s
# 42933: done 569 episodes, mean reward -0.066, speed 50.44 f/s
# Test done in 9.52 sec, reward 0.001, steps 123
# 43031: done 570 episodes, mean reward -0.074, speed 8.68 f/s
# 43098: done 571 episodes, mean reward -0.080, speed 51.88 f/s
# 43176: done 572 episodes, mean reward -0.081, speed 55.79 f/s
# 43372: done 574 episodes, mean reward -0.087, speed 56.09 f/s
# 43439: done 575 episodes, mean reward -0.086, speed 54.97 f/s
# 43512: done 576 episodes, mean reward -0.087, speed 53.82 f/s
# 43749: done 577 episodes, mean reward -0.097, speed 60.32 f/s
# Test done in 15.61 sec, reward -0.484, steps 213
# 44256: done 578 episodes, mean reward -0.112, speed 21.13 f/s
# 44371: done 579 episodes, mean reward -0.112, speed 57.28 f/s
# 44468: done 580 episodes, mean reward -0.113, speed 56.60 f/s
# 44663: done 581 episodes, mean reward -0.122, speed 59.31 f/s
# 44924: done 582 episodes, mean reward -0.124, speed 59.36 f/s
# 44997: done 583 episodes, mean reward -0.123, speed 55.27 f/s
# Test done in 9.55 sec, reward 0.001, steps 115
# 45219: done 584 episodes, mean reward -0.129, speed 16.66 f/s
# 45295: done 585 episodes, mean reward -0.131, speed 51.63 f/s
# 45380: done 586 episodes, mean reward -0.132, speed 54.71 f/s
# 45651: done 587 episodes, mean reward -0.136, speed 58.50 f/s
# 45702: done 588 episodes, mean reward -0.135, speed 50.38 f/s
# 45790: done 589 episodes, mean reward -0.137, speed 56.85 f/s
# 45853: done 590 episodes, mean reward -0.139, speed 53.01 f/s
# 45958: done 591 episodes, mean reward -0.139, speed 58.66 f/s
# Test done in 12.97 sec, reward -0.418, steps 168
# 46146: done 592 episodes, mean reward -0.148, speed 11.54 f/s
# 46265: done 593 episodes, mean reward -0.153, speed 54.16 f/s
# 46327: done 594 episodes, mean reward -0.153, speed 53.47 f/s
# 46405: done 595 episodes, mean reward -0.152, speed 53.44 f/s
# 46475: done 596 episodes, mean reward -0.158, speed 53.01 f/s
# 46556: done 597 episodes, mean reward -0.164, speed 53.30 f/s
# 46633: done 598 episodes, mean reward -0.164, speed 53.82 f/s
# 46750: done 599 episodes, mean reward -0.172, speed 55.33 f/s
# Test done in 20.59 sec, reward -0.926, steps 274
# 47263: done 600 episodes, mean reward -0.183, speed 17.47 f/s
# 47336: done 601 episodes, mean reward -0.184, speed 52.64 f/s
# 47546: done 602 episodes, mean reward -0.192, speed 56.21 f/s
# 47711: done 604 episodes, mean reward -0.197, speed 52.78 f/s
# 47871: done 605 episodes, mean reward -0.201, speed 56.41 f/s
# Test done in 8.97 sec, reward -0.346, steps 102
# 48017: done 606 episodes, mean reward -0.205, speed 12.66 f/s
# 48124: done 607 episodes, mean reward -0.208, speed 54.35 f/s
# 48197: done 608 episodes, mean reward -0.214, speed 52.89 f/s
# 48262: done 609 episodes, mean reward -0.217, speed 54.18 f/s
# 48338: done 610 episodes, mean reward -0.220, speed 51.32 f/s
# 48532: done 611 episodes, mean reward -0.225, speed 57.41 f/s
# 48597: done 612 episodes, mean reward -0.227, speed 53.00 f/s
# 48704: done 613 episodes, mean reward -0.226, speed 54.47 f/s
# 48774: done 614 episodes, mean reward -0.225, speed 52.80 f/s
# 48841: done 615 episodes, mean reward -0.231, speed 50.83 f/s
# Test done in 11.06 sec, reward -0.443, steps 126
# 49162: done 616 episodes, mean reward -0.237, speed 19.30 f/s
# 49359: done 617 episodes, mean reward -0.245, speed 56.14 f/s
# 49424: done 618 episodes, mean reward -0.233, speed 52.19 f/s
# 49498: done 619 episodes, mean reward -0.235, speed 52.32 f/s
# 49548: done 620 episodes, mean reward -0.233, speed 49.40 f/s
# 49808: done 621 episodes, mean reward -0.234, speed 55.12 f/s
# 49925: done 622 episodes, mean reward -0.233, speed 57.08 f/s
# Test done in 9.99 sec, reward -0.208, steps 118
# 50005: done 623 episodes, mean reward -0.237, speed 6.95 f/s
# 50067: done 624 episodes, mean reward -0.238, speed 53.86 f/s
# 50140: done 625 episodes, mean reward -0.236, speed 55.15 f/s
# 50407: done 627 episodes, mean reward -0.238, speed 59.08 f/s
# 50574: done 628 episodes, mean reward -0.234, speed 58.09 f/s
# 50672: done 630 episodes, mean reward -0.232, speed 51.37 f/s
# 50767: done 631 episodes, mean reward -0.233, speed 55.94 f/s
# Test done in 10.65 sec, reward -0.177, steps 132
# 51049: done 632 episodes, mean reward -0.235, speed 18.14 f/s
# 51106: done 633 episodes, mean reward -0.234, speed 49.27 f/s
# 51242: done 635 episodes, mean reward -0.235, speed 53.31 f/s
# 51322: done 636 episodes, mean reward -0.237, speed 51.20 f/s
# 51505: done 637 episodes, mean reward -0.233, speed 57.63 f/s
# 51761: done 638 episodes, mean reward -0.233, speed 57.65 f/s
# 51836: done 639 episodes, mean reward -0.232, speed 54.92 f/s
# 51993: done 640 episodes, mean reward -0.236, speed 56.24 f/s
# Test done in 8.69 sec, reward -0.273, steps 106
# 52073: done 641 episodes, mean reward -0.239, speed 7.87 f/s
# 52158: done 642 episodes, mean reward -0.242, speed 54.75 f/s
# 52304: done 643 episodes, mean reward -0.246, speed 57.82 f/s
# 52375: done 644 episodes, mean reward -0.250, speed 53.84 f/s
# 52536: done 645 episodes, mean reward -0.253, speed 55.61 f/s
# 52926: done 646 episodes, mean reward -0.257, speed 59.81 f/s
# Test done in 10.78 sec, reward -0.219, steps 134
# 53033: done 647 episodes, mean reward -0.257, speed 8.43 f/s
# 53209: done 648 episodes, mean reward -0.261, speed 61.56 f/s
# 53340: done 650 episodes, mean reward -0.261, speed 55.62 f/s
# 53409: done 651 episodes, mean reward -0.262, speed 56.34 f/s
# 53507: done 652 episodes, mean reward -0.262, speed 56.04 f/s
# 53615: done 654 episodes, mean reward -0.266, speed 50.75 f/s
# 53681: done 655 episodes, mean reward -0.265, speed 53.92 f/s
# 53788: done 656 episodes, mean reward -0.267, speed 55.95 f/s
# 53982: done 657 episodes, mean reward -0.270, speed 57.17 f/s
# Test done in 12.04 sec, reward -0.191, steps 155
# 54139: done 658 episodes, mean reward -0.270, speed 10.59 f/s
# 54197: done 659 episodes, mean reward -0.269, speed 52.71 f/s
# 54283: done 660 episodes, mean reward -0.266, speed 56.09 f/s
# 54377: done 661 episodes, mean reward -0.266, speed 56.55 f/s
# 54535: done 662 episodes, mean reward -0.265, speed 56.60 f/s
# 54730: done 663 episodes, mean reward -0.262, speed 57.59 f/s
# 54815: done 664 episodes, mean reward -0.265, speed 56.01 f/s
# 54917: done 665 episodes, mean reward -0.268, speed 53.93 f/s
# 54999: done 666 episodes, mean reward -0.267, speed 54.49 f/s
# Test done in 8.69 sec, reward 0.026, steps 106
# 55074: done 667 episodes, mean reward -0.268, speed 7.39 f/s
# 55137: done 668 episodes, mean reward -0.270, speed 51.22 f/s
# 55211: done 669 episodes, mean reward -0.273, speed 55.06 f/s
# 55274: done 670 episodes, mean reward -0.269, speed 52.25 f/s
# 55353: done 671 episodes, mean reward -0.268, speed 54.16 f/s
# 55488: done 672 episodes, mean reward -0.270, speed 53.51 f/s
# 55572: done 673 episodes, mean reward -0.271, speed 51.86 f/s
# 55704: done 674 episodes, mean reward -0.272, speed 58.16 f/s
# 55770: done 675 episodes, mean reward -0.272, speed 53.47 f/s
# 55852: done 676 episodes, mean reward -0.272, speed 57.54 f/s
# Test done in 10.17 sec, reward -0.367, steps 116
# 56026: done 677 episodes, mean reward -0.267, speed 13.32 f/s
# 56119: done 678 episodes, mean reward -0.253, speed 55.79 f/s
# 56302: done 679 episodes, mean reward -0.254, speed 58.71 f/s
# 56422: done 680 episodes, mean reward -0.252, speed 56.58 f/s
# 56496: done 681 episodes, mean reward -0.244, speed 52.79 f/s
# 56610: done 682 episodes, mean reward -0.245, speed 56.13 f/s
# 56676: done 683 episodes, mean reward -0.247, speed 52.66 f/s
# 56792: done 684 episodes, mean reward -0.244, speed 53.96 f/s
# 56866: done 685 episodes, mean reward -0.241, speed 52.49 f/s
# Test done in 11.50 sec, reward -0.317, steps 138
# 57041: done 686 episodes, mean reward -0.243, speed 12.01 f/s
# 57214: done 687 episodes, mean reward -0.244, speed 59.26 f/s
# 57285: done 688 episodes, mean reward -0.244, speed 52.64 f/s
# 57368: done 689 episodes, mean reward -0.244, speed 55.59 f/s
# 57554: done 690 episodes, mean reward -0.245, speed 56.97 f/s
# 57646: done 691 episodes, mean reward -0.244, speed 53.95 f/s
# 57809: done 692 episodes, mean reward -0.242, speed 56.45 f/s
# 57979: done 693 episodes, mean reward -0.242, speed 53.88 f/s
# Test done in 9.18 sec, reward -0.444, steps 114
# 58013: done 694 episodes, mean reward -0.241, speed 3.44 f/s
# 58105: done 696 episodes, mean reward -0.237, speed 52.85 f/s
# 58289: done 697 episodes, mean reward -0.238, speed 58.73 f/s
# 58374: done 698 episodes, mean reward -0.241, speed 55.56 f/s
# 58463: done 699 episodes, mean reward -0.240, speed 53.93 f/s
# 58576: done 700 episodes, mean reward -0.231, speed 57.15 f/s
# 58670: done 701 episodes, mean reward -0.232, speed 56.49 f/s
# 58758: done 702 episodes, mean reward -0.226, speed 56.63 f/s
# Test done in 10.94 sec, reward -0.216, steps 145
# 59315: done 703 episodes, mean reward -0.233, speed 27.74 f/s
# 59454: done 704 episodes, mean reward -0.226, speed 59.09 f/s
# 59542: done 705 episodes, mean reward -0.221, speed 56.72 f/s
# 59800: done 707 episodes, mean reward -0.216, speed 57.76 f/s
# 59966: done 709 episodes, mean reward -0.210, speed 57.16 f/s
# Test done in 9.36 sec, reward -0.350, steps 122
# 60239: done 710 episodes, mean reward -0.209, speed 19.59 f/s
# 60537: done 711 episodes, mean reward -0.200, speed 60.79 f/s
# 60664: done 712 episodes, mean reward -0.197, speed 58.04 f/s
# 60871: done 713 episodes, mean reward -0.201, speed 59.81 f/s
# Test done in 9.04 sec, reward -0.069, steps 111
# 61050: done 714 episodes, mean reward -0.202, speed 14.73 f/s
# 61375: done 715 episodes, mean reward -0.207, speed 62.33 f/s
# 61763: done 716 episodes, mean reward -0.205, speed 62.16 f/s
# Test done in 6.30 sec, reward 0.031, steps 73
# 62010: done 717 episodes, mean reward -0.199, speed 23.70 f/s
# 62072: done 718 episodes, mean reward -0.197, speed 53.52 f/s
# 62215: done 719 episodes, mean reward -0.196, speed 59.27 f/s
# 62336: done 720 episodes, mean reward -0.198, speed 58.28 f/s
# 62396: done 721 episodes, mean reward -0.194, speed 52.71 f/s
# 62461: done 722 episodes, mean reward -0.194, speed 54.35 f/s
# 62636: done 723 episodes, mean reward -0.191, speed 59.00 f/s
# 62834: done 724 episodes, mean reward -0.189, speed 60.54 f/s
# 62892: done 725 episodes, mean reward -0.187, speed 54.60 f/s
# 62961: done 726 episodes, mean reward -0.186, speed 52.94 f/s
# Test done in 11.32 sec, reward -0.277, steps 151
# 63130: done 727 episodes, mean reward -0.187, speed 11.97 f/s
# 63306: done 728 episodes, mean reward -0.184, speed 58.88 f/s
# 63420: done 729 episodes, mean reward -0.182, speed 57.19 f/s
# 63479: done 730 episodes, mean reward -0.179, speed 52.29 f/s
# 63578: done 732 episodes, mean reward -0.170, speed 52.51 f/s
# 63667: done 733 episodes, mean reward -0.170, speed 56.60 f/s
# 63733: done 734 episodes, mean reward -0.167, speed 54.16 f/s
# 63809: done 735 episodes, mean reward -0.166, speed 53.80 f/s
# 63918: done 736 episodes, mean reward -0.165, speed 56.98 f/s
# Test done in 10.58 sec, reward -0.184, steps 146
# 64010: done 737 episodes, mean reward -0.164, speed 7.58 f/s
# 64105: done 738 episodes, mean reward -0.163, speed 57.24 f/s
# 64290: done 739 episodes, mean reward -0.162, speed 59.41 f/s
# 64489: done 740 episodes, mean reward -0.162, speed 58.29 f/s
# 64561: done 741 episodes, mean reward -0.161, speed 52.92 f/s
# 64652: done 742 episodes, mean reward -0.158, speed 55.10 f/s
# 64807: done 743 episodes, mean reward -0.153, speed 59.51 f/s
# 64901: done 744 episodes, mean reward -0.151, speed 55.63 f/s
# Test done in 9.39 sec, reward -0.079, steps 121
# 65094: done 745 episodes, mean reward -0.149, speed 15.29 f/s
# 65245: done 746 episodes, mean reward -0.143, speed 59.70 f/s
# 65340: done 748 episodes, mean reward -0.133, speed 52.25 f/s
# 65416: done 749 episodes, mean reward -0.132, speed 53.77 f/s
# 65516: done 750 episodes, mean reward -0.135, speed 54.86 f/s
# 65725: done 752 episodes, mean reward -0.128, speed 56.84 f/s
# 65979: done 753 episodes, mean reward -0.128, speed 60.96 f/s
# Test done in 7.63 sec, reward 0.081, steps 91
# 66136: done 754 episodes, mean reward -0.123, speed 15.21 f/s
# 66210: done 755 episodes, mean reward -0.122, speed 55.69 f/s
# 66283: done 756 episodes, mean reward -0.120, speed 56.65 f/s
# 66391: done 757 episodes, mean reward -0.114, speed 58.06 f/s
# 66448: done 758 episodes, mean reward -0.112, speed 54.71 f/s
# 66505: done 760 episodes, mean reward -0.115, speed 47.18 f/s
# 66569: done 762 episodes, mean reward -0.114, speed 48.75 f/s
# 66640: done 764 episodes, mean reward -0.111, speed 49.68 f/s
# 66707: done 766 episodes, mean reward -0.108, speed 50.13 f/s
# 66767: done 768 episodes, mean reward -0.108, speed 47.89 f/s
# 66844: done 770 episodes, mean reward -0.105, speed 50.51 f/s
# 66913: done 772 episodes, mean reward -0.101, speed 48.79 f/s
# 66990: done 774 episodes, mean reward -0.097, speed 49.13 f/s
# Test done in 3.94 sec, reward 0.010, steps 37
# 67018: done 775 episodes, mean reward -0.097, speed 6.14 f/s
# 67078: done 777 episodes, mean reward -0.089, speed 47.76 f/s
# 67178: done 779 episodes, mean reward -0.088, speed 53.05 f/s
# 67245: done 781 episodes, mean reward -0.087, speed 47.26 f/s
# 67312: done 783 episodes, mean reward -0.084, speed 48.21 f/s
# 67372: done 785 episodes, mean reward -0.081, speed 47.65 f/s
# 67440: done 787 episodes, mean reward -0.075, speed 47.23 f/s
# 67507: done 789 episodes, mean reward -0.074, speed 47.55 f/s
# 67572: done 791 episodes, mean reward -0.068, speed 46.87 f/s
# 67640: done 792 episodes, mean reward -0.062, speed 50.90 f/s
# 67717: done 794 episodes, mean reward -0.058, speed 48.01 f/s
# 67790: done 796 episodes, mean reward -0.058, speed 48.34 f/s
# 67911: done 798 episodes, mean reward -0.052, speed 52.81 f/s
# Test done in 4.91 sec, reward -0.087, steps 46
# 68002: done 799 episodes, mean reward -0.048, speed 13.96 f/s
# 68071: done 801 episodes, mean reward -0.046, speed 47.18 f/s
# 68133: done 802 episodes, mean reward -0.046, speed 54.53 f/s
# 68223: done 804 episodes, mean reward -0.041, speed 50.27 f/s
# 68281: done 805 episodes, mean reward -0.041, speed 51.68 f/s
# 68365: done 807 episodes, mean reward -0.040, speed 51.33 f/s
# 68459: done 809 episodes, mean reward -0.039, speed 51.55 f/s
# 68558: done 811 episodes, mean reward -0.040, speed 51.18 f/s
# 68619: done 812 episodes, mean reward -0.040, speed 51.77 f/s
# 68711: done 814 episodes, mean reward -0.030, speed 50.13 f/s
# 68783: done 816 episodes, mean reward -0.017, speed 47.20 f/s
# 68844: done 817 episodes, mean reward -0.014, speed 53.56 f/s
# 68932: done 819 episodes, mean reward -0.011, speed 51.46 f/s
# Test done in 4.82 sec, reward 0.016, steps 49
# 69002: done 821 episodes, mean reward -0.010, speed 11.07 f/s
# 69141: done 823 episodes, mean reward -0.008, speed 54.45 f/s
# 69242: done 825 episodes, mean reward -0.009, speed 51.92 f/s
# 69385: done 827 episodes, mean reward -0.002, speed 53.49 f/s
# 69479: done 828 episodes, mean reward -0.002, speed 56.61 f/s
# 69562: done 829 episodes, mean reward -0.001, speed 56.67 f/s
# 69615: done 830 episodes, mean reward -0.001, speed 51.72 f/s
# 69681: done 831 episodes, mean reward -0.001, speed 52.93 f/s
# 69880: done 833 episodes, mean reward 0.002, speed 57.05 f/s
# 69965: done 835 episodes, mean reward -0.001, speed 51.02 f/s
# Test done in 5.01 sec, reward 0.057, steps 54
# 70030: done 836 episodes, mean reward -0.001, speed 10.52 f/s
# 70154: done 838 episodes, mean reward 0.002, speed 54.73 f/s
# 70248: done 840 episodes, mean reward 0.007, speed 51.35 f/s
# 70349: done 842 episodes, mean reward 0.007, speed 51.44 f/s
# 70412: done 843 episodes, mean reward 0.006, speed 52.66 f/s
# 70524: done 845 episodes, mean reward 0.009, speed 52.06 f/s
# 70635: done 847 episodes, mean reward 0.007, speed 52.49 f/s
# 70744: done 849 episodes, mean reward 0.009, speed 53.72 f/s
# 70859: done 850 episodes, mean reward 0.013, speed 58.42 f/s
# 70914: done 851 episodes, mean reward 0.013, speed 52.98 f/s
# Test done in 4.99 sec, reward -0.042, steps 52
# 71007: done 853 episodes, mean reward 0.010, speed 13.68 f/s
# 71061: done 854 episodes, mean reward 0.009, speed 51.14 f/s
# 71171: done 856 episodes, mean reward 0.008, speed 52.47 f/s
# 71235: done 857 episodes, mean reward 0.008, speed 53.15 f/s
# 71343: done 859 episodes, mean reward 0.007, speed 53.10 f/s
# 71411: done 860 episodes, mean reward 0.007, speed 53.34 f/s
# 71499: done 861 episodes, mean reward 0.006, speed 57.09 f/s
# 71561: done 862 episodes, mean reward 0.007, speed 52.83 f/s
# 71653: done 864 episodes, mean reward 0.008, speed 52.14 f/s
# 71729: done 865 episodes, mean reward 0.007, speed 53.34 f/s
# 71786: done 866 episodes, mean reward 0.005, speed 52.34 f/s
# 71876: done 868 episodes, mean reward 0.006, speed 51.77 f/s
# 71946: done 869 episodes, mean reward 0.004, speed 54.82 f/s
# Test done in 4.83 sec, reward 0.000, steps 52
# 72026: done 870 episodes, mean reward 0.006, speed 12.82 f/s
# 72084: done 871 episodes, mean reward 0.006, speed 50.90 f/s
# 72181: done 873 episodes, mean reward 0.009, speed 53.34 f/s
# 72236: done 874 episodes, mean reward 0.011, speed 52.93 f/s
# 72324: done 876 episodes, mean reward 0.012, speed 50.96 f/s
# 72380: done 877 episodes, mean reward 0.013, speed 53.36 f/s
# 72445: done 878 episodes, mean reward 0.014, speed 54.97 f/s
# 72516: done 879 episodes, mean reward 0.012, speed 54.74 f/s
# 72583: done 880 episodes, mean reward 0.011, speed 54.23 f/s
# 72698: done 882 episodes, mean reward 0.011, speed 53.25 f/s
# 72806: done 883 episodes, mean reward 0.015, speed 58.31 f/s
# 72902: done 884 episodes, mean reward 0.017, speed 60.06 f/s
# 72957: done 885 episodes, mean reward 0.016, speed 54.70 f/s
# Test done in 4.95 sec, reward -0.152, steps 52
# 73137: done 887 episodes, mean reward 0.012, speed 22.20 f/s
# 73254: done 888 episodes, mean reward 0.015, speed 58.10 f/s
# 73345: done 890 episodes, mean reward 0.015, speed 50.25 f/s
# 73410: done 891 episodes, mean reward 0.015, speed 55.37 f/s
# 73465: done 892 episodes, mean reward 0.015, speed 52.00 f/s
# 73546: done 894 episodes, mean reward 0.014, speed 50.29 f/s
# 73599: done 895 episodes, mean reward 0.015, speed 52.95 f/s
# 73774: done 896 episodes, mean reward 0.013, speed 59.73 f/s
# 73861: done 898 episodes, mean reward 0.012, speed 52.36 f/s
# 73971: done 900 episodes, mean reward 0.014, speed 52.09 f/s
# Test done in 5.31 sec, reward 0.010, steps 59
# 74017: done 901 episodes, mean reward 0.016, speed 7.40 f/s
# 74069: done 902 episodes, mean reward 0.017, speed 51.71 f/s
# 74153: done 903 episodes, mean reward 0.014, speed 54.89 f/s
# 74217: done 904 episodes, mean reward 0.015, speed 51.82 f/s
# 74289: done 905 episodes, mean reward 0.015, speed 56.04 f/s
# 74386: done 907 episodes, mean reward 0.013, speed 52.95 f/s
# 74480: done 909 episodes, mean reward 0.010, speed 52.15 f/s
# 74541: done 910 episodes, mean reward 0.010, speed 52.96 f/s
# 74594: done 911 episodes, mean reward 0.007, speed 52.18 f/s
# 74690: done 913 episodes, mean reward 0.007, speed 52.43 f/s
# 74875: done 915 episodes, mean reward 0.006, speed 56.52 f/s
# 74934: done 916 episodes, mean reward 0.007, speed 54.23 f/s
# Test done in 7.05 sec, reward -0.012, steps 84
# 75045: done 918 episodes, mean reward 0.007, speed 12.14 f/s
# 75138: done 919 episodes, mean reward 0.009, speed 56.12 f/s
# 75274: done 920 episodes, mean reward 0.010, speed 60.49 f/s
# 75387: done 922 episodes, mean reward 0.011, speed 53.93 f/s
# 75569: done 924 episodes, mean reward 0.007, speed 57.38 f/s
# 75703: done 925 episodes, mean reward 0.009, speed 61.50 f/s
# 75799: done 926 episodes, mean reward 0.006, speed 60.76 f/s
# 75937: done 928 episodes, mean reward 0.003, speed 58.04 f/s
# Test done in 8.63 sec, reward 0.162, steps 112
# Best reward updated: 0.098 -> 0.162
# 76075: done 929 episodes, mean reward 0.003, speed 12.64 f/s
# 76179: done 930 episodes, mean reward 0.003, speed 57.99 f/s
# 76312: done 931 episodes, mean reward 0.002, speed 58.22 f/s
# 76401: done 932 episodes, mean reward 0.002, speed 54.69 f/s
# 76468: done 933 episodes, mean reward -0.002, speed 53.72 f/s
# 76657: done 934 episodes, mean reward -0.006, speed 60.06 f/s
# 76851: done 935 episodes, mean reward -0.008, speed 59.91 f/s
# Test done in 7.79 sec, reward -0.037, steps 98
# 77136: done 936 episodes, mean reward -0.017, speed 22.98 f/s
# 77219: done 937 episodes, mean reward -0.017, speed 56.98 f/s
# 77338: done 938 episodes, mean reward -0.020, speed 59.29 f/s
# 77475: done 939 episodes, mean reward -0.021, speed 58.73 f/s
# 77929: done 941 episodes, mean reward -0.028, speed 60.51 f/s
# 77985: done 942 episodes, mean reward -0.026, speed 53.21 f/s
# Test done in 9.45 sec, reward 0.367, steps 127
# Best reward updated: 0.162 -> 0.367
# 78117: done 943 episodes, mean reward -0.025, speed 11.30 f/s
# 78512: done 944 episodes, mean reward -0.037, speed 59.35 f/s
# 78589: done 945 episodes, mean reward -0.037, speed 56.96 f/s
# 78694: done 947 episodes, mean reward -0.037, speed 52.95 f/s
# 78754: done 949 episodes, mean reward -0.040, speed 48.85 f/s
# Test done in 15.05 sec, reward -0.650, steps 210
# 79234: done 951 episodes, mean reward -0.058, speed 20.76 f/s
# 79361: done 953 episodes, mean reward -0.056, speed 54.14 f/s
# 79485: done 954 episodes, mean reward -0.053, speed 57.23 f/s
# 79555: done 955 episodes, mean reward -0.053, speed 55.02 f/s
# 79831: done 956 episodes, mean reward -0.053, speed 60.65 f/s
# 79908: done 957 episodes, mean reward -0.055, speed 55.95 f/s
# Test done in 10.42 sec, reward -0.191, steps 139
# 80040: done 959 episodes, mean reward -0.053, speed 10.21 f/s
# 80111: done 960 episodes, mean reward -0.053, speed 54.94 f/s
# 80211: done 961 episodes, mean reward -0.051, speed 56.78 f/s
# 80354: done 963 episodes, mean reward -0.054, speed 55.87 f/s
# 80438: done 964 episodes, mean reward -0.053, speed 56.07 f/s
# 80608: done 965 episodes, mean reward -0.054, speed 59.16 f/s
# Test done in 10.55 sec, reward 0.103, steps 141
# 81175: done 966 episodes, mean reward -0.065, speed 28.87 f/s
# 81253: done 968 episodes, mean reward -0.066, speed 52.90 f/s
# 81329: done 969 episodes, mean reward -0.065, speed 58.63 f/s
# 81496: done 971 episodes, mean reward -0.069, speed 56.14 f/s
# 81634: done 972 episodes, mean reward -0.073, speed 57.49 f/s
# 81816: done 973 episodes, mean reward -0.072, speed 59.57 f/s
# 81961: done 975 episodes, mean reward -0.071, speed 54.22 f/s
# Test done in 10.55 sec, reward 0.063, steps 140
# 82363: done 976 episodes, mean reward -0.078, speed 23.41 f/s
# 82527: done 978 episodes, mean reward -0.078, speed 56.45 f/s
# 82582: done 979 episodes, mean reward -0.078, speed 51.24 f/s
# 82726: done 980 episodes, mean reward -0.075, speed 59.61 f/s
# 82782: done 981 episodes, mean reward -0.075, speed 51.67 f/s
# 82898: done 982 episodes, mean reward -0.072, speed 57.17 f/s
# Test done in 8.87 sec, reward 0.093, steps 113
# 83026: done 983 episodes, mean reward -0.072, speed 11.59 f/s
# 83187: done 984 episodes, mean reward -0.075, speed 58.61 f/s
# 83305: done 985 episodes, mean reward -0.071, speed 57.70 f/s
# 83477: done 987 episodes, mean reward -0.068, speed 56.63 f/s
# 83993: done 989 episodes, mean reward -0.065, speed 62.25 f/s
# Test done in 8.65 sec, reward 0.076, steps 111
# 84124: done 990 episodes, mean reward -0.063, speed 12.01 f/s
# 84223: done 991 episodes, mean reward -0.059, speed 57.09 f/s
# 84303: done 993 episodes, mean reward -0.057, speed 50.01 f/s
# 84438: done 994 episodes, mean reward -0.054, speed 57.31 f/s
# 84653: done 995 episodes, mean reward -0.050, speed 61.37 f/s
# 84928: done 996 episodes, mean reward -0.046, speed 59.25 f/s
# Test done in 15.38 sec, reward 0.424, steps 218
# Best reward updated: 0.367 -> 0.424
# 85408: done 997 episodes, mean reward -0.035, speed 20.79 f/s
# 85773: done 998 episodes, mean reward -0.028, speed 61.48 f/s
# ...
# 743797: done 4948 episodes, mean reward 0.356, speed 59.81 f/s
# 743855: done 4949 episodes, mean reward 0.357, speed 52.78 f/s
# Test done in 7.29 sec, reward 0.318, steps 83
# 744045: done 4950 episodes, mean reward 0.356, speed 18.00 f/s
# 744159: done 4951 episodes, mean reward 0.356, speed 57.19 f/s
# 744287: done 4952 episodes, mean reward 0.355, speed 58.52 f/s
# 744461: done 4953 episodes, mean reward 0.352, speed 58.75 f/s
# Test done in 8.37 sec, reward 0.286, steps 98
# 745004: done 4954 episodes, mean reward 0.346, speed 31.53 f/s
# 745207: done 4956 episodes, mean reward 0.347, speed 56.66 f/s
# 745292: done 4957 episodes, mean reward 0.347, speed 54.21 f/s
# Test done in 11.44 sec, reward 0.249, steps 141
# 746292: done 4958 episodes, mean reward 0.353, speed 36.30 f/s
# 746821: done 4959 episodes, mean reward 0.350, speed 60.39 f/s
# Test done in 5.37 sec, reward 0.298, steps 54
# 747074: done 4960 episodes, mean reward 0.348, speed 26.15 f/s
# 747578: done 4961 episodes, mean reward 0.350, speed 60.94 f/s
# Test done in 4.57 sec, reward 0.275, steps 44
# 748616: done 4963 episodes, mean reward 0.358, speed 47.79 f/s
# 748959: done 4964 episodes, mean reward 0.364, speed 61.25 f/s
# Test done in 4.55 sec, reward 0.289, steps 43
# 749189: done 4965 episodes, mean reward 0.360, speed 27.30 f/s
# Test done in 4.41 sec, reward 0.279, steps 42
# 750035: done 4966 episodes, mean reward 0.362, speed 46.87 f/s
# 750207: done 4967 episodes, mean reward 0.362, speed 59.82 f/s
# 750302: done 4968 episodes, mean reward 0.355, speed 55.59 f/s
# 750493: done 4969 episodes, mean reward 0.351, speed 59.03 f/s
# Test done in 6.62 sec, reward 0.339, steps 74
# 751205: done 4970 episodes, mean reward 0.354, speed 39.09 f/s
# 751547: done 4971 episodes, mean reward 0.347, speed 60.41 f/s
# 751657: done 4972 episodes, mean reward 0.348, speed 56.34 f/s
# 751758: done 4973 episodes, mean reward 0.349, speed 56.61 f/s
# Test done in 5.11 sec, reward 0.304, steps 51
# 752612: done 4974 episodes, mean reward 0.354, speed 45.01 f/s
# 752864: done 4975 episodes, mean reward 0.360, speed 59.52 f/s
# 752959: done 4976 episodes, mean reward 0.362, speed 55.85 f/s
# Test done in 6.31 sec, reward 0.325, steps 70
# 753257: done 4978 episodes, mean reward 0.359, speed 26.19 f/s
# 753313: done 4979 episodes, mean reward 0.360, speed 52.67 f/s
# 753929: done 4980 episodes, mean reward 0.361, speed 61.37 f/s
# Test done in 5.60 sec, reward 0.351, steps 58
# 754047: done 4981 episodes, mean reward 0.360, speed 15.52 f/s
# 754477: done 4982 episodes, mean reward 0.351, speed 59.74 f/s
# Test done in 5.19 sec, reward 0.306, steps 52
# 755296: done 4983 episodes, mean reward 0.357, speed 44.42 f/s
# 755451: done 4984 episodes, mean reward 0.360, speed 56.51 f/s
# 755813: done 4985 episodes, mean reward 0.361, speed 60.24 f/s
# Test done in 5.97 sec, reward 0.373, steps 64
# 756047: done 4986 episodes, mean reward 0.359, speed 23.58 f/s
# 756107: done 4987 episodes, mean reward 0.362, speed 51.89 f/s
# 756433: done 4988 episodes, mean reward 0.366, speed 60.22 f/s
# 756616: done 4989 episodes, mean reward 0.368, speed 58.34 f/s
# 756965: done 4990 episodes, mean reward 0.374, speed 60.45 f/s
# Test done in 4.84 sec, reward 0.281, steps 48
# 757039: done 4991 episodes, mean reward 0.378, speed 12.00 f/s
# 757921: done 4992 episodes, mean reward 0.378, speed 61.22 f/s
# 757978: done 4993 episodes, mean reward 0.380, speed 53.05 f/s
# Test done in 5.21 sec, reward 0.313, steps 52
# 758011: done 4994 episodes, mean reward 0.378, speed 5.59 f/s
# 758216: done 4995 episodes, mean reward 0.377, speed 59.32 f/s
# 758394: done 4996 episodes, mean reward 0.379, speed 57.85 f/s
# 758951: done 4997 episodes, mean reward 0.384, speed 61.02 f/s
# Test done in 5.60 sec, reward 0.335, steps 58
# 759338: done 4998 episodes, mean reward 0.387, speed 32.05 f/s
# 759446: done 4999 episodes, mean reward 0.385, speed 56.33 f/s
# 759951: done 5000 episodes, mean reward 0.393, speed 61.23 f/s
# Test done in 5.56 sec, reward 0.346, steps 58
# 760053: done 5001 episodes, mean reward 0.396, speed 13.88 f/s
# 760109: done 5002 episodes, mean reward 0.397, speed 52.43 f/s
# 760176: done 5003 episodes, mean reward 0.400, speed 54.85 f/s
# 760279: done 5004 episodes, mean reward 0.396, speed 56.77 f/s
# 760509: done 5005 episodes, mean reward 0.399, speed 62.37 f/s
# Test done in 6.86 sec, reward 0.355, steps 78
# 761509: done 5006 episodes, mean reward 0.409, speed 43.79 f/s
# Test done in 9.37 sec, reward 0.395, steps 114
# 762060: done 5007 episodes, mean reward 0.414, speed 29.69 f/s
# 762113: done 5008 episodes, mean reward 0.417, speed 51.29 f/s
# 762185: done 5009 episodes, mean reward 0.404, speed 55.99 f/s
# 762325: done 5011 episodes, mean reward 0.406, speed 54.89 f/s
# Test done in 7.39 sec, reward 0.311, steps 84
# 763047: done 5012 episodes, mean reward 0.410, speed 37.34 f/s
# 763405: done 5013 episodes, mean reward 0.410, speed 61.08 f/s
# Test done in 5.31 sec, reward 0.306, steps 53
# 764003: done 5014 episodes, mean reward 0.415, speed 40.14 f/s
# 764067: done 5015 episodes, mean reward 0.411, speed 51.99 f/s
# 764383: done 5016 episodes, mean reward 0.413, speed 59.36 f/s
# 764562: done 5017 episodes, mean reward 0.418, speed 58.95 f/s
# 764712: done 5018 episodes, mean reward 0.417, speed 58.29 f/s
# 764770: done 5019 episodes, mean reward 0.411, speed 52.80 f/s
# Test done in 4.44 sec, reward 0.273, steps 42
# 765770: done 5020 episodes, mean reward 0.415, speed 48.68 f/s
# Test done in 13.81 sec, reward 0.301, steps 169
# 766090: done 5022 episodes, mean reward 0.404, speed 16.57 f/s
# 766941: done 5023 episodes, mean reward 0.418, speed 61.51 f/s
# Test done in 4.63 sec, reward 0.253, steps 43
# 767097: done 5024 episodes, mean reward 0.413, speed 21.39 f/s
# 767186: done 5025 episodes, mean reward 0.415, speed 55.10 f/s
# 767374: done 5026 episodes, mean reward 0.416, speed 59.55 f/s
# 767616: done 5027 episodes, mean reward 0.417, speed 61.32 f/s
# 767885: done 5028 episodes, mean reward 0.416, speed 59.71 f/s
# Test done in 8.96 sec, reward 0.285, steps 108
# 768053: done 5029 episodes, mean reward 0.413, speed 14.20 f/s
# 768174: done 5030 episodes, mean reward 0.410, speed 57.10 f/s
# 768598: done 5031 episodes, mean reward 0.415, speed 60.75 f/s
# 768673: done 5032 episodes, mean reward 0.418, speed 54.62 f/s
# Test done in 5.19 sec, reward 0.295, steps 52
# 769587: done 5033 episodes, mean reward 0.420, speed 45.60 f/s
# 769965: done 5034 episodes, mean reward 0.425, speed 61.35 f/s
# Test done in 11.45 sec, reward 0.305, steps 141
# 770018: done 5035 episodes, mean reward 0.422, speed 4.25 f/s
# 770426: done 5036 episodes, mean reward 0.426, speed 60.55 f/s
# Test done in 5.14 sec, reward 0.298, steps 50
# 771094: done 5037 episodes, mean reward 0.426, speed 41.62 f/s
# 771247: done 5039 episodes, mean reward 0.427, speed 55.35 f/s
# Test done in 7.78 sec, reward 0.371, steps 92
# 772089: done 5040 episodes, mean reward 0.421, speed 39.03 f/s
# 772196: done 5041 episodes, mean reward 0.426, speed 56.32 f/s
# 772311: done 5043 episodes, mean reward 0.422, speed 53.04 f/s
# 772469: done 5045 episodes, mean reward 0.425, speed 55.19 f/s
# 772752: done 5046 episodes, mean reward 0.422, speed 58.73 f/s
# 772823: done 5047 episodes, mean reward 0.419, speed 53.56 f/s
# Test done in 5.69 sec, reward 0.312, steps 60
# 773074: done 5048 episodes, mean reward 0.422, speed 25.36 f/s
# 773154: done 5049 episodes, mean reward 0.423, speed 53.50 f/s
# 773788: done 5050 episodes, mean reward 0.431, speed 61.42 f/s
# Test done in 13.62 sec, reward 0.286, steps 161
# 774384: done 5051 episodes, mean reward 0.432, speed 25.63 f/s
# 774526: done 5052 episodes, mean reward 0.434, speed 58.68 f/s
# 774854: done 5053 episodes, mean reward 0.432, speed 60.30 f/s
# Test done in 5.48 sec, reward 0.315, steps 57
# 775540: done 5054 episodes, mean reward 0.448, speed 41.26 f/s
# 775611: done 5056 episodes, mean reward 0.443, speed 48.23 f/s
# 775683: done 5057 episodes, mean reward 0.443, speed 55.46 f/s
# Test done in 5.08 sec, reward 0.313, steps 51
# 776311: done 5058 episodes, mean reward 0.443, speed 40.68 f/s
# 776566: done 5060 episodes, mean reward 0.444, speed 57.44 f/s
# Test done in 16.49 sec, reward 0.406, steps 217
# 777556: done 5061 episodes, mean reward 0.458, speed 30.58 f/s
# Test done in 5.79 sec, reward 0.350, steps 61
# 778556: done 5062 episodes, mean reward 0.462, speed 44.91 f/s
# 778874: done 5063 episodes, mean reward 0.457, speed 59.82 f/s
# Test done in 10.09 sec, reward 0.342, steps 122
# 779006: done 5064 episodes, mean reward 0.450, speed 10.66 f/s
# 779414: done 5065 episodes, mean reward 0.457, speed 60.04 f/s
# 779535: done 5067 episodes, mean reward 0.455, speed 53.85 f/s
# Test done in 15.74 sec, reward 0.350, steps 209
# 780012: done 5069 episodes, mean reward 0.457, speed 20.10 f/s
# 780847: done 5070 episodes, mean reward 0.456, speed 61.87 f/s
# 780927: done 5071 episodes, mean reward 0.457, speed 57.32 f/s
# Test done in 4.72 sec, reward 0.275, steps 47
# 781006: done 5072 episodes, mean reward 0.457, speed 12.75 f/s
# 781224: done 5073 episodes, mean reward 0.454, speed 59.99 f/s
# 781821: done 5074 episodes, mean reward 0.456, speed 61.65 f/s
# 781893: done 5075 episodes, mean reward 0.453, speed 54.75 f/s
# Test done in 13.46 sec, reward 0.333, steps 171
# 782048: done 5076 episodes, mean reward 0.452, speed 9.61 f/s
# 782481: done 5077 episodes, mean reward 0.450, speed 61.39 f/s
# 782724: done 5078 episodes, mean reward 0.452, speed 57.19 f/s
# 782797: done 5079 episodes, mean reward 0.452, speed 53.88 f/s
# 782893: done 5080 episodes, mean reward 0.449, speed 56.67 f/s
# 782979: done 5081 episodes, mean reward 0.449, speed 58.30 f/s
# Test done in 5.85 sec, reward 0.303, steps 64
# 783331: done 5082 episodes, mean reward 0.453, speed 30.23 f/s
# 783481: done 5083 episodes, mean reward 0.445, speed 58.90 f/s
# 783594: done 5084 episodes, mean reward 0.446, speed 57.09 f/s
# Test done in 4.95 sec, reward 0.290, steps 50
# 784592: done 5085 episodes, mean reward 0.452, speed 47.16 f/s
# Test done in 7.19 sec, reward 0.321, steps 85
# 785457: done 5086 episodes, mean reward 0.461, speed 41.15 f/s
# 785553: done 5087 episodes, mean reward 0.463, speed 57.35 f/s
# 785963: done 5088 episodes, mean reward 0.459, speed 62.08 f/s
# Test done in 5.64 sec, reward 0.335, steps 61
# 786210: done 5089 episodes, mean reward 0.462, speed 25.50 f/s
# 786384: done 5090 episodes, mean reward 0.462, speed 59.69 f/s
# 786470: done 5091 episodes, mean reward 0.461, speed 56.70 f/s
# 786585: done 5092 episodes, mean reward 0.453, speed 57.74 f/s
# 786781: done 5093 episodes, mean reward 0.453, speed 59.69 f/s
# Test done in 7.32 sec, reward 0.298, steps 88
# 787315: done 5094 episodes, mean reward 0.463, speed 33.74 f/s
# 787389: done 5095 episodes, mean reward 0.462, speed 54.37 f/s
# 787632: done 5097 episodes, mean reward 0.452, speed 57.55 f/s
# 787827: done 5098 episodes, mean reward 0.448, speed 60.05 f/s
# Test done in 6.33 sec, reward 0.342, steps 72
# 788293: done 5099 episodes, mean reward 0.450, speed 33.80 f/s
# 788393: done 5100 episodes, mean reward 0.445, speed 58.01 f/s
# 788511: done 5101 episodes, mean reward 0.444, speed 60.67 f/s
# 788874: done 5102 episodes, mean reward 0.455, speed 63.14 f/s
# Test done in 4.93 sec, reward 0.318, steps 54
# 789015: done 5103 episodes, mean reward 0.456, speed 19.30 f/s
# 789575: done 5104 episodes, mean reward 0.461, speed 62.93 f/s
# 789728: done 5105 episodes, mean reward 0.460, speed 61.08 f/s
# 789890: done 5106 episodes, mean reward 0.457, speed 60.49 f/s
# 789989: done 5107 episodes, mean reward 0.454, speed 57.41 f/s
# Test done in 4.25 sec, reward 0.268, steps 42
# 790115: done 5108 episodes, mean reward 0.456, speed 19.89 f/s
# 790212: done 5109 episodes, mean reward 0.458, speed 60.08 f/s
# 790616: done 5111 episodes, mean reward 0.456, speed 62.02 f/s
# 790691: done 5112 episodes, mean reward 0.454, speed 55.39 f/s
# Test done in 4.42 sec, reward 0.256, steps 45
# 791691: done 5113 episodes, mean reward 0.460, speed 49.29 f/s
# 791854: done 5114 episodes, mean reward 0.457, speed 59.54 f/s
# Test done in 4.15 sec, reward 0.234, steps 40
# 792103: done 5116 episodes, mean reward 0.456, speed 29.50 f/s
# 792335: done 5118 episodes, mean reward 0.453, speed 57.34 f/s
# 792634: done 5119 episodes, mean reward 0.451, speed 62.10 f/s
# Test done in 4.10 sec, reward 0.239, steps 41
# 793073: done 5121 episodes, mean reward 0.452, speed 38.79 f/s
# 793195: done 5122 episodes, mean reward 0.456, speed 58.17 f/s
# 793377: done 5123 episodes, mean reward 0.441, speed 59.69 f/s
# 793610: done 5125 episodes, mean reward 0.443, speed 58.65 f/s
# Test done in 8.38 sec, reward 0.278, steps 107
# 794610: done 5126 episodes, mean reward 0.463, speed 40.99 f/s
# 794723: done 5127 episodes, mean reward 0.461, speed 57.25 f/s
# 794851: done 5129 episodes, mean reward 0.455, speed 55.80 f/s
# Test done in 5.86 sec, reward 0.300, steps 65
# 795642: done 5130 episodes, mean reward 0.463, speed 43.03 f/s
# 795781: done 5132 episodes, mean reward 0.459, speed 55.01 f/s
# Test done in 8.41 sec, reward 0.311, steps 105
# 796250: done 5133 episodes, mean reward 0.458, speed 29.54 f/s
# 796336: done 5134 episodes, mean reward 0.452, speed 57.43 f/s
# 796651: done 5136 episodes, mean reward 0.445, speed 59.50 f/s
# 796924: done 5137 episodes, mean reward 0.444, speed 60.42 f/s
# Test done in 7.74 sec, reward 0.277, steps 92
# 797023: done 5138 episodes, mean reward 0.446, speed 10.49 f/s
# 797157: done 5139 episodes, mean reward 0.448, speed 58.24 f/s
# 797516: done 5140 episodes, mean reward 0.461, speed 60.63 f/s
# 797756: done 5141 episodes, mean reward 0.458, speed 62.00 f/s
# Test done in 4.27 sec, reward 0.254, steps 41
# 798326: done 5142 episodes, mean reward 0.467, speed 42.80 f/s
# 798627: done 5144 episodes, mean reward 0.469, speed 58.57 f/s
# 798773: done 5145 episodes, mean reward 0.466, speed 57.64 f/s
# 798891: done 5146 episodes, mean reward 0.466, speed 57.91 f/s
# Test done in 4.19 sec, reward 0.238, steps 40
# 799294: done 5147 episodes, mean reward 0.476, speed 37.38 f/s
# 799371: done 5149 episodes, mean reward 0.471, speed 50.28 f/s
# 799593: done 5151 episodes, mean reward 0.459, speed 57.45 f/s
# 799776: done 5153 episodes, mean reward 0.462, speed 57.71 f/s
# 799961: done 5154 episodes, mean reward 0.450, speed 59.59 f/s
# Test done in 5.83 sec, reward 0.273, steps 65
# 800374: done 5155 episodes, mean reward 0.462, speed 32.88 f/s
# 800562: done 5157 episodes, mean reward 0.460, speed 56.41 f/s
# 800769: done 5158 episodes, mean reward 0.456, speed 61.29 f/s
# 800836: done 5159 episodes, mean reward 0.456, speed 53.43 f/s
# 800939: done 5160 episodes, mean reward 0.456, speed 56.86 f/s
# Test done in 6.01 sec, reward 0.286, steps 69
# 801307: done 5161 episodes, mean reward 0.441, speed 31.30 f/s
# 801553: done 5162 episodes, mean reward 0.445, speed 60.91 f/s
# Test done in 4.51 sec, reward 0.250, steps 44
# 802175: done 5163 episodes, mean reward 0.449, speed 42.49 f/s
# 802575: done 5165 episodes, mean reward 0.453, speed 59.44 f/s
# 802742: done 5166 episodes, mean reward 0.461, speed 59.14 f/s
# Test done in 4.90 sec, reward 0.241, steps 50
# 803322: done 5167 episodes, mean reward 0.466, speed 40.69 f/s
# Test done in 6.98 sec, reward 0.286, steps 80
# 804189: done 5168 episodes, mean reward 0.478, speed 41.61 f/s
# 804260: done 5169 episodes, mean reward 0.476, speed 56.00 f/s
# 804494: done 5170 episodes, mean reward 0.473, speed 62.09 f/s
# 804623: done 5171 episodes, mean reward 0.471, speed 61.84 f/s
# Test done in 4.16 sec, reward 0.261, steps 42
# 805111: done 5173 episodes, mean reward 0.477, speed 41.32 f/s
# 805422: done 5174 episodes, mean reward 0.474, speed 62.18 f/s
# 805516: done 5176 episodes, mean reward 0.469, speed 51.46 f/s
# 805628: done 5178 episodes, mean reward 0.470, speed 53.30 f/s
# 805730: done 5179 episodes, mean reward 0.472, speed 56.81 f/s
# Test done in 19.71 sec, reward 0.310, steps 259
# 806444: done 5180 episodes, mean reward 0.477, speed 23.07 f/s
# 806635: done 5181 episodes, mean reward 0.480, speed 60.91 f/s
# 806922: done 5182 episodes, mean reward 0.477, speed 62.13 f/s
# Test done in 4.48 sec, reward 0.254, steps 46
# 807081: done 5183 episodes, mean reward 0.476, speed 22.42 f/s

# %% [markdown]
# # **episode**

# %%
# video recorder import
from gym.wrappers.monitoring.video_recorder import VideoRecorder

# video -> html function
from base64 import b64encode
def render_mp4(videopath: str) -> str:
  """
  Gets a string containing a b4-encoded version of the MP4 video
  at the specified path.
  """
  mp4 = open(videopath, 'rb').read()
  base64_encoded_mp4 = b64encode(mp4).decode()
  return f'<video width=400 controls><source src="data:video/mp4;' \
         f'base64,{base64_encoded_mp4}" type="video/mp4"></video>'

# %%
# setup env & download model

env = gym.make("MinitaurBulletEnv-v0")

net = DDPGActor(env.observation_space.shape[0], env.action_space.shape[0])
net.load_state_dict(torch.load('mount/My Drive/Colab Notebooks/minitaur_/01_22053122/act_net.pth'))
# Out:
# urdf_root=/usr/local/lib/python3.7/dist-packages/pybullet_data
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# <All keys matched successfully>

# %%
# video record

minitaur_training = "minitaur_training.mp4"
video = VideoRecorder(env, minitaur_training)

steps = 0
rewards = 0

state = env.reset()
done = False
while not done:
  env.render()
  video.capture_frame()

  state = torch.tensor(state, dtype=torch.float)
  action_draft = net(state)
  action = action_draft.squeeze(dim=0).data.cpu().numpy()
  action = np.clip(action, -1, 1)
  next_state, reward, done, info = env.step(action)

  state = next_state
  steps += 1
  rewards += reward

  pass

env.render()
video.capture_frame()

video.close()
env.close()

# %%
print('steps:', steps)
print('rewards:', rewards)
# Out:
# steps: 141
# rewards: 0.5795669862606598

# %%
# video play

from IPython.display import HTML
html = render_mp4(minitaur_training)
HTML(html)
# Out:
# <video width=400 controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %% [markdown]
# # **Assess**

# %%
# setup env & download model

env = gym.make("MinitaurBulletEnv-v0")

net = DDPGActor(env.observation_space.shape[0], env.action_space.shape[0])
net.load_state_dict(torch.load('mount/My Drive/Colab Notebooks/minitaur_/01_22053122/act_net.pth'))
# Out:
# urdf_root=/usr/local/lib/python3.7/dist-packages/pybullet_data
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# <All keys matched successfully>

# %%
# simulate

rewords_by_episodes = []
steps_by_episodes = []

for i in range(100):

  rewords = 0
  steps = 0

  state = env.reset()
  done = False
  while not done:

    state = torch.tensor(state, dtype=torch.float)
    action_draft = net(state)
    action = action_draft.squeeze(dim=0).data.cpu().numpy()
    action = np.clip(action, -1, 1)
    next_state, reword, done, info = env.step(action)

    state = next_state
    rewords += reword
    steps += 1

    pass

  rewords_by_episodes.append(rewords)
  steps_by_episodes.append(steps)

  pass

env.close()

# %%
# plot

import matplotlib.pyplot as plt

fig, ax = plt.subplots(2)
ax[0].plot(rewords_by_episodes)
ax[1].plot(steps_by_episodes)
