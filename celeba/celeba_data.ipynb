# %% [markdown]
# <a href="https://colab.research.google.com/github/carp-x/ML_Colab/blob/main/celeba/celeba_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('./mount')
# Out:
# Mounted at ./mount

# %%
import h5py

import numpy
import matplotlib.pyplot as plt

# %%
# open HDF5 file and list any groups

with h5py.File('mount/My Drive/Colab Notebooks/celeba/celeba_aligned_small.h5py', 'r') as file_object:

  for group in file_object:
    print(group)
    pass
# Out:
# img_align_celeba

# %%
# open HDF5 file, extract example image as numpy array and plot it

with h5py.File('mount/My Drive/Colab Notebooks/celeba/celeba_aligned_small.h5py', 'r') as file_object:
  dataset = file_object['img_align_celeba']
  image = numpy.array(dataset['2409.jpg'])
  plt.imshow(image, interpolation='none')
  pass

# %%
#shape of the image array

image.shape
# Out:
# (218, 178, 3)
